# %%
try:
    import pandas as pd
    import numpy as np
    from numpy import set_printoptions
    import os,sys
    import re
    # importing algorithms
    from sklearn.model_selection import train_test_split
    from sklearn.linear_model import LogisticRegression
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.naive_bayes import GaussianNB
    from sklearn.naive_bayes import MultinomialNB
    from sklearn.naive_bayes import BernoulliNB
    from sklearn import svm
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import confusion_matrix, classification_report
    from sklearn.preprocessing import MinMaxScaler
except Exception as e:
    print("Error is due to",e)
pwd = os.getcwd()

# %%
# Reading labels
labels_df = pd.read_csv(pwd+"//Datasets//Kabita//Input//kabita_dataset_labels.csv")
labels_df
# Out:
#       kabita_labels
# 0                 7
# 1                 7
# 2                 4
# 3                 2
# 4                 7
# ...             ...
# 4895              1
# 4896              1
# 4897              1
# 4898              4
# 4899              1
#
# [4900 rows x 1 columns]

# %% [markdown]
# ### Modelling on Transformers vectorized data

# %% [markdown]
# ### BERT Sentence transformer Base Model

# %%
# reading dataset
bert_df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//bert_vectorized_kabita_dataset.csv")
x_train,x_test,y_train,y_test = train_test_split(bert_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=12,stratify=labels_df['kabita_labels'])
print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    bert_knn_model = KNeighborsClassifier(n_neighbors=x)
    bert_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          bert_knn_model.score(x_test,y_test))
    pred = bert_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

#sys.exit()
# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
bert_knn_model = KNeighborsClassifier(n_neighbors=70)
bert_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", bert_knn_model.score(x_test,y_test))
pred = bert_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
bert_lr_model = LogisticRegression(max_iter=2000)
bert_lr_model.fit(x_train,y_train)
bert_lr_pred_val = bert_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", bert_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,bert_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,bert_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
bert_gnb_model = GaussianNB()
bert_gnb_model.fit(x_train,y_train)
bert_gnb_pred_val = bert_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", bert_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,bert_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,bert_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
bert_bnb_model = BernoulliNB()
bert_bnb_model.fit(x_train,y_train)
bert_bnb_pred_val = bert_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", bert_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,bert_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,bert_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    bert_svm_model = svm.SVC(kernel=a_kernel)
    bert_svm_model.fit(x_train,y_train)
    bert_svm_pred_val = bert_svm_model.predict(x_test)
    print("Working on SVM Kernal:", a_kernel)
    print("Accuracy of SVM model is:", bert_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,bert_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,bert_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    bert_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    bert_dt_model.fit(x_train,y_train)
    bert_dt_pred_val = bert_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), bert_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    bert_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    bert_rf_model.fit(x_train,y_train)
    bert_rf_pred_val = bert_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), bert_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
bert_mnb_model = MultinomialNB()
bert_mnb_model.fit(m_train,y_train)
bert_mnb_pred_val = bert_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", bert_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,bert_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,bert_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.6755102040816326
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[154   5   6   5  32   7   1]
#  [  7 162   9   2  23   6   1]
#  [  3   7 192   4   1   3   0]
#  [ 18  25  15 120  20   8   4]
#  [ 24  28   5  10 138   2   3]
#  [ 29  15   8  22  11  72  53]
#  [  6   4   0  13  11  21 155]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.64      0.73      0.68       210
#            2       0.66      0.77      0.71       210
#            3       0.82      0.91      0.86       210
#            4       0.68      0.57      0.62       210
#            5       0.58      0.66      0.62       210
#            6       0.61      0.34      0.44       210
#            7       0.71      0.74      0.73       210
#
#     accuracy                           0.68      1470
#    macro avg       0.67      0.68      0.67      1470
# ...

# %% [markdown]
# ### BERT Sentence transformer Ganesh Bert Hinglish

# %%
# reading dataset
bert_df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//bert_vectorized_kabita_dataset_gkb.csv")
x_train,x_test,y_train,y_test = train_test_split(bert_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=12,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    bert_knn_model = KNeighborsClassifier(n_neighbors=x)
    bert_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          bert_knn_model.score(x_test,y_test))
    pred = bert_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
bert_knn_model = KNeighborsClassifier(n_neighbors=70)
bert_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", bert_knn_model.score(x_test,y_test))
pred = bert_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
bert_lr_model = LogisticRegression(max_iter=2000)
bert_lr_model.fit(x_train,y_train)
bert_lr_pred_val = bert_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", bert_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,bert_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,bert_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
bert_gnb_model = GaussianNB()
bert_gnb_model.fit(x_train,y_train)
bert_gnb_pred_val = bert_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", bert_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,bert_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,bert_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
bert_bnb_model = BernoulliNB()
bert_bnb_model.fit(x_train,y_train)
bert_bnb_pred_val = bert_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", bert_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,bert_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,bert_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    bert_svm_model = svm.SVC(kernel=a_kernel)
    bert_svm_model.fit(x_train,y_train)
    bert_svm_pred_val = bert_svm_model.predict(x_test)
    print("Working on SVM Kernel:", a_kernel)
    print("Accuracy of SVM model is:", bert_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,bert_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,bert_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    bert_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    bert_dt_model.fit(x_train,y_train)
    bert_dt_pred_val = bert_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), bert_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    bert_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    bert_rf_model.fit(x_train,y_train)
    bert_rf_pred_val = bert_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), bert_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
bert_mnb_model = MultinomialNB()
bert_mnb_model.fit(m_train,y_train)
bert_mnb_pred_val = bert_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", bert_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,bert_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,bert_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.44421768707482995
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[133  24   5  14  19   8   7]
#  [ 33 113  16  16  23   5   4]
#  [ 12  14 176   2   5   1   0]
#  [ 78  30   8  47  28   7  12]
#  [ 62  42   4  19  69   5   9]
#  [ 44  27  10  25  18  38  48]
#  [ 38  16   1  13  26  39  77]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.33      0.63      0.44       210
#            2       0.42      0.54      0.47       210
#            3       0.80      0.84      0.82       210
#            4       0.35      0.22      0.27       210
#            5       0.37      0.33      0.35       210
#            6       0.37      0.18      0.24       210
#            7       0.49      0.37      0.42       210
#
#     accuracy                           0.44      1470
#    macro avg       0.45      0.44      0.43      1470
# ...

# %% [markdown]
# ### BERT Sentence transformer Narasimha distilbert Hinglish

# %%
# reading dataset
bert_df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//bert_vectorized_kabita_dataset_ndisbert.csv")
x_train,x_test,y_train,y_test = train_test_split(bert_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=12,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    bert_knn_model = KNeighborsClassifier(n_neighbors=x)
    bert_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          bert_knn_model.score(x_test,y_test))
    pred = bert_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
bert_knn_model = KNeighborsClassifier(n_neighbors=70)
bert_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", bert_knn_model.score(x_test,y_test))
pred = bert_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
bert_lr_model = LogisticRegression(max_iter=2000)
bert_lr_model.fit(x_train,y_train)
bert_lr_pred_val = bert_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", bert_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,bert_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,bert_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
bert_gnb_model = GaussianNB()
bert_gnb_model.fit(x_train,y_train)
bert_gnb_pred_val = bert_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", bert_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,bert_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,bert_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
bert_bnb_model = BernoulliNB()
bert_bnb_model.fit(x_train,y_train)
bert_bnb_pred_val = bert_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", bert_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,bert_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,bert_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    bert_svm_model = svm.SVC(kernel=a_kernel)
    bert_svm_model.fit(x_train,y_train)
    bert_svm_pred_val = bert_svm_model.predict(x_test)
    print("Working on SVM kernel:", a_kernel)
    print("Accuracy of SVM model is:", bert_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,bert_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,bert_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    bert_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    bert_dt_model.fit(x_train,y_train)
    bert_dt_pred_val = bert_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), bert_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    bert_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    bert_rf_model.fit(x_train,y_train)
    bert_rf_pred_val = bert_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), bert_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
bert_mnb_model = MultinomialNB()
bert_mnb_model.fit(m_train,y_train)
bert_mnb_pred_val = bert_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", bert_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,bert_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,bert_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.6510204081632653
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[154   3   1   4  41   2   5]
#  [  8 156   5   3  25   6   7]
#  [  8   5 186   3   5   2   1]
#  [ 36  17  13 100  29  10   5]
#  [ 44  16  10   7 124   2   7]
#  [ 24  16   3  15  14  61  77]
#  [  5   4   0   0   9  16 176]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.55      0.73      0.63       210
#            2       0.72      0.74      0.73       210
#            3       0.85      0.89      0.87       210
#            4       0.76      0.48      0.58       210
#            5       0.50      0.59      0.54       210
#            6       0.62      0.29      0.39       210
#            7       0.63      0.84      0.72       210
#
#     accuracy                           0.65      1470
#    macro avg       0.66      0.65      0.64      1470
# ...

# %% [markdown]
# ### BERT Sentence transformer verloop bert hinglish

# %%
# reading dataset
bert_df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//bert_vectorized_kabita_dataset_vbert.csv")
x_train,x_test,y_train,y_test = train_test_split(bert_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=12,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    bert_knn_model = KNeighborsClassifier(n_neighbors=x)
    bert_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          bert_knn_model.score(x_test,y_test))
    pred = bert_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
bert_knn_model = KNeighborsClassifier(n_neighbors=70)
bert_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", bert_knn_model.score(x_test,y_test))
pred = bert_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
bert_lr_model = LogisticRegression(max_iter=2000)
bert_lr_model.fit(x_train,y_train)
bert_lr_pred_val = bert_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", bert_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,bert_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,bert_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
bert_gnb_model = GaussianNB()
bert_gnb_model.fit(x_train,y_train)
bert_gnb_pred_val = bert_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", bert_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,bert_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,bert_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
bert_bnb_model = BernoulliNB()
bert_bnb_model.fit(x_train,y_train)
bert_bnb_pred_val = bert_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", bert_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,bert_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,bert_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    bert_svm_model = svm.SVC(kernel=a_kernel)
    bert_svm_model.fit(x_train,y_train)
    bert_svm_pred_val = bert_svm_model.predict(x_test)
    print("Working on SVM kernel:", a_kernel)
    print("Accuracy of SVM model is:", bert_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,bert_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,bert_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    bert_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    bert_dt_model.fit(x_train,y_train)
    bert_dt_pred_val = bert_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), bert_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    bert_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    bert_rf_model.fit(x_train,y_train)
    bert_rf_pred_val = bert_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), bert_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
bert_mnb_model = MultinomialNB()
bert_mnb_model.fit(m_train,y_train)
bert_mnb_pred_val = bert_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", bert_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,bert_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,bert_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.6612244897959184
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[156   7   3   2  36   3   3]
#  [  4 173   6   6  21   0   0]
#  [  6   8 188   4   3   0   1]
#  [ 24  13  10 118  33   5   7]
#  [ 48  23  12  11 109   0   7]
#  [ 29  16  11  25  17  60  52]
#  [  7   1   0   5  16  13 168]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.57      0.74      0.64       210
#            2       0.72      0.82      0.77       210
#            3       0.82      0.90      0.85       210
#            4       0.69      0.56      0.62       210
#            5       0.46      0.52      0.49       210
#            6       0.74      0.29      0.41       210
#            7       0.71      0.80      0.75       210
#
#     accuracy                           0.66      1470
#    macro avg       0.67      0.66      0.65      1470
# ...

# %% [markdown]
# ### BERT Fine tuned transformer Base Model

# %%
# reading dataset
bert_df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//bert_base_finetuned_vectorized_kabita_dataset.csv")
x_train,x_test,y_train,y_test = train_test_split(bert_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=12,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    bert_knn_model = KNeighborsClassifier(n_neighbors=x)
    bert_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          bert_knn_model.score(x_test,y_test))
    pred = bert_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
bert_knn_model = KNeighborsClassifier(n_neighbors=70)
bert_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", bert_knn_model.score(x_test,y_test))
pred = bert_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
bert_lr_model = LogisticRegression(max_iter=2000)
bert_lr_model.fit(x_train,y_train)
bert_lr_pred_val = bert_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", bert_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,bert_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,bert_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
bert_gnb_model = GaussianNB()
bert_gnb_model.fit(x_train,y_train)
bert_gnb_pred_val = bert_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", bert_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,bert_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,bert_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
bert_bnb_model = BernoulliNB()
bert_bnb_model.fit(x_train,y_train)
bert_bnb_pred_val = bert_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", bert_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,bert_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,bert_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    bert_svm_model = svm.SVC(kernel=a_kernel)
    bert_svm_model.fit(x_train,y_train)
    bert_svm_pred_val = bert_svm_model.predict(x_test)
    print("Working on SVM kernel:", a_kernel)
    print("Accuracy of SVM model is:", bert_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,bert_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,bert_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    bert_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    bert_dt_model.fit(x_train,y_train)
    bert_dt_pred_val = bert_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), bert_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    bert_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    bert_rf_model.fit(x_train,y_train)
    bert_rf_pred_val = bert_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), bert_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
bert_mnb_model = MultinomialNB()
bert_mnb_model.fit(m_train,y_train)
bert_mnb_pred_val = bert_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", bert_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,bert_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,bert_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.5394557823129251
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[140   4   0  11  29  11  15]
#  [ 19 133   4  10  32   5   7]
#  [  5  14 173   7   8   2   1]
#  [ 46  22  12  75  31   9  15]
#  [ 43  18   7  21 102   2  17]
#  [ 45  23   3  41  17  40  41]
#  [ 23   7   1  18  17  14 130]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.44      0.67      0.53       210
#            2       0.60      0.63      0.62       210
#            3       0.86      0.82      0.84       210
#            4       0.41      0.36      0.38       210
#            5       0.43      0.49      0.46       210
#            6       0.48      0.19      0.27       210
#            7       0.58      0.62      0.60       210
#
#     accuracy                           0.54      1470
#    macro avg       0.54      0.54      0.53      1470
# ...

# %% [markdown]
# ### BERT Fine tuned transformer Hinglish Model

# %%
# reading dataset
bert_df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//vbert_hinglish_finetuned_vectorized_kabita_dataset.csv")
x_train,x_test,y_train,y_test = train_test_split(bert_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=12,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    bert_knn_model = KNeighborsClassifier(n_neighbors=x)
    bert_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          bert_knn_model.score(x_test,y_test))
    pred = bert_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
bert_knn_model = KNeighborsClassifier(n_neighbors=70)
bert_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", bert_knn_model.score(x_test,y_test))
pred = bert_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
bert_lr_model = LogisticRegression(max_iter=2000)
bert_lr_model.fit(x_train,y_train)
bert_lr_pred_val = bert_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", bert_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,bert_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,bert_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
bert_gnb_model = GaussianNB()
bert_gnb_model.fit(x_train,y_train)
bert_gnb_pred_val = bert_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", bert_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,bert_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,bert_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
bert_bnb_model = BernoulliNB()
bert_bnb_model.fit(x_train,y_train)
bert_bnb_pred_val = bert_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", bert_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,bert_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,bert_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    bert_svm_model = svm.SVC(kernel=a_kernel)
    bert_svm_model.fit(x_train,y_train)
    bert_svm_pred_val = bert_svm_model.predict(x_test)
    print("Working on SVM kernel:", a_kernel)
    print("Accuracy of SVM model is:", bert_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,bert_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,bert_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    bert_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    bert_dt_model.fit(x_train,y_train)
    bert_dt_pred_val = bert_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), bert_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    bert_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    bert_rf_model.fit(x_train,y_train)
    bert_rf_pred_val = bert_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), bert_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,bert_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,bert_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
bert_mnb_model = MultinomialNB()
bert_mnb_model.fit(m_train,y_train)
bert_mnb_pred_val = bert_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", bert_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,bert_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,bert_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.6040816326530613
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[130   6   6  12  41   8   7]
#  [ 12 155   5   2  30   4   2]
#  [ 11   3 181   4   6   5   0]
#  [ 40  12  14  84  54   5   1]
#  [ 40  22   3  11 124   2   8]
#  [ 44  14   8  16  19  55  54]
#  [ 13   5   2   9  12  10 159]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.45      0.62      0.52       210
#            2       0.71      0.74      0.73       210
#            3       0.83      0.86      0.84       210
#            4       0.61      0.40      0.48       210
#            5       0.43      0.59      0.50       210
#            6       0.62      0.26      0.37       210
#            7       0.69      0.76      0.72       210
#
#     accuracy                           0.60      1470
#    macro avg       0.62      0.60      0.59      1470
# ...

# %% [markdown]
# ### GPT2 Sentence Transformer

# %%
# reading dataset
gpt_df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//gpt_vectorized_kabita_dataset.csv")

x_train,x_test,y_train,y_test = train_test_split(gpt_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=13,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    gpt_knn_model = KNeighborsClassifier(n_neighbors=x)
    gpt_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          gpt_knn_model.score(x_test,y_test))
    pred = gpt_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
gpt_knn_model = KNeighborsClassifier(n_neighbors=70)
gpt_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", gpt_knn_model.score(x_test,y_test))
pred = gpt_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
gpt_lr_model = LogisticRegression(max_iter=2000)
gpt_lr_model.fit(x_train,y_train)
gpt_lr_pred_val = gpt_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", gpt_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,gpt_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,gpt_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
gpt_gnb_model = GaussianNB()
gpt_gnb_model.fit(x_train,y_train)
gpt_gnb_pred_val = gpt_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", gpt_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,gpt_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,gpt_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
gpt_bnb_model = BernoulliNB()
gpt_bnb_model.fit(x_train,y_train)
gpt_bnb_pred_val = gpt_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", gpt_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,gpt_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,gpt_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    gpt_svm_model = svm.SVC(kernel=a_kernel)
    gpt_svm_model.fit(x_train,y_train)
    gpt_svm_pred_val = gpt_svm_model.predict(x_test)
    print("Working on SVM kernel:", a_kernel)
    print("Accuracy of SVM model is:", gpt_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,gpt_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,gpt_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    gpt_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    gpt_dt_model.fit(x_train,y_train)
    gpt_dt_pred_val = gpt_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), gpt_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,gpt_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,gpt_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    gpt_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    gpt_rf_model.fit(x_train,y_train)
    gpt_rf_pred_val = gpt_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), gpt_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,gpt_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,gpt_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
gpt_mnb_model = MultinomialNB()
gpt_mnb_model.fit(m_train,y_train)
gpt_mnb_pred_val = gpt_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", gpt_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,gpt_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,gpt_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.6469387755102041
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[157   4   4   6  33   6   0]
#  [ 12 166   8   4  16   3   1]
#  [  5   4 188   8   2   2   1]
#  [ 30  10  23 124  15   7   1]
#  [ 47  36   9  15  92   3   8]
#  [ 40  16  14  19   5  70  46]
#  [ 21   6   1   9   4  15 154]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.50      0.75      0.60       210
#            2       0.69      0.79      0.73       210
#            3       0.76      0.90      0.82       210
#            4       0.67      0.59      0.63       210
#            5       0.55      0.44      0.49       210
#            6       0.66      0.33      0.44       210
#            7       0.73      0.73      0.73       210
#
#     accuracy                           0.65      1470
#    macro avg       0.65      0.65      0.64      1470
# ...

# %% [markdown]
# ### GPT2 Fine tuned transformer Base model

# %%
# reading dataset
gpt_df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//gpt_base_finetuned_vectorized_kabita_dataset.csv")

x_train,x_test,y_train,y_test = train_test_split(gpt_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=13,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    gpt_knn_model = KNeighborsClassifier(n_neighbors=x)
    gpt_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          gpt_knn_model.score(x_test,y_test))
    pred = gpt_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
gpt_knn_model = KNeighborsClassifier(n_neighbors=70)
gpt_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", gpt_knn_model.score(x_test,y_test))
pred = gpt_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
gpt_lr_model = LogisticRegression(max_iter=2000)
gpt_lr_model.fit(x_train,y_train)
gpt_lr_pred_val = gpt_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", gpt_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,gpt_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,gpt_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
gpt_gnb_model = GaussianNB()
gpt_gnb_model.fit(x_train,y_train)
gpt_gnb_pred_val = gpt_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", gpt_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,gpt_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,gpt_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
gpt_bnb_model = BernoulliNB()
gpt_bnb_model.fit(x_train,y_train)
gpt_bnb_pred_val = gpt_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", gpt_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,gpt_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,gpt_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    gpt_svm_model = svm.SVC(kernel=a_kernel)
    gpt_svm_model.fit(x_train,y_train)
    gpt_svm_pred_val = gpt_svm_model.predict(x_test)
    print("Working on SVM kernel:", a_kernel)
    print("Accuracy of SVM model is:", gpt_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,gpt_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,gpt_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    gpt_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    gpt_dt_model.fit(x_train,y_train)
    gpt_dt_pred_val = gpt_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), gpt_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,gpt_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,gpt_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    gpt_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    gpt_rf_model.fit(x_train,y_train)
    gpt_rf_pred_val = gpt_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), gpt_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,gpt_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,gpt_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
gpt_mnb_model = MultinomialNB()
gpt_mnb_model.fit(m_train,y_train)
gpt_mnb_pred_val = gpt_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", gpt_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,gpt_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,gpt_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.46802721088435373
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[129   9   4  23  27  11   7]
#  [ 15 132  11  18  23   8   3]
#  [ 11  19 157  12   7   4   0]
#  [ 40  33  13  78  21  14  11]
#  [ 65  32   3  28  66   5  11]
#  [ 48  26  13  29  17  39  38]
#  [ 22  22   0  40  16  23  87]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.39      0.61      0.48       210
#            2       0.48      0.63      0.55       210
#            3       0.78      0.75      0.76       210
#            4       0.34      0.37      0.36       210
#            5       0.37      0.31      0.34       210
#            6       0.38      0.19      0.25       210
#            7       0.55      0.41      0.47       210
#
#     accuracy                           0.47      1470
#    macro avg       0.47      0.47      0.46      1470
# ...

# %% [markdown]
# ### GPT2 Fine tuned transformer Hinglish model

# %%
# reading dataset
gpt_df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//gpt_hinglish_finetuned_vectorized_kabita_dataset.csv")

x_train,x_test,y_train,y_test = train_test_split(gpt_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=13,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    gpt_knn_model = KNeighborsClassifier(n_neighbors=x)
    gpt_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          gpt_knn_model.score(x_test,y_test))
    pred = gpt_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
gpt_knn_model = KNeighborsClassifier(n_neighbors=70)
gpt_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", gpt_knn_model.score(x_test,y_test))
pred = gpt_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
gpt_lr_model = LogisticRegression(max_iter=2000)
gpt_lr_model.fit(x_train,y_train)
gpt_lr_pred_val = gpt_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", gpt_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,gpt_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,gpt_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
gpt_gnb_model = GaussianNB()
gpt_gnb_model.fit(x_train,y_train)
gpt_gnb_pred_val = gpt_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", gpt_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,gpt_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,gpt_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
gpt_bnb_model = BernoulliNB()
gpt_bnb_model.fit(x_train,y_train)
gpt_bnb_pred_val = gpt_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", gpt_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,gpt_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,gpt_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    gpt_svm_model = svm.SVC(kernel=a_kernel)
    gpt_svm_model.fit(x_train,y_train)
    gpt_svm_pred_val = gpt_svm_model.predict(x_test)
    print("Working on SVM kernel:", a_kernel)
    print("Accuracy of SVM model is:", gpt_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,gpt_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,gpt_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    gpt_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    gpt_dt_model.fit(x_train,y_train)
    gpt_dt_pred_val = gpt_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), gpt_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,gpt_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,gpt_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    gpt_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    gpt_rf_model.fit(x_train,y_train)
    gpt_rf_pred_val = gpt_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), gpt_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,gpt_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,gpt_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
gpt_mnb_model = MultinomialNB()
gpt_mnb_model.fit(m_train,y_train)
gpt_mnb_pred_val = gpt_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", gpt_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,gpt_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,gpt_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.45714285714285713
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[107  10   5  12  46  11  19]
#  [ 19 126   5  16  28   4  12]
#  [ 12  21 154  13   7   1   2]
#  [ 39  19   5  84  35  14  14]
#  [ 56  16   4  26  91   6  11]
#  [ 31  42   8  47  18  26  38]
#  [ 38  14   1  28  20  25  84]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.35      0.51      0.42       210
#            2       0.51      0.60      0.55       210
#            3       0.85      0.73      0.79       210
#            4       0.37      0.40      0.39       210
#            5       0.37      0.43      0.40       210
#            6       0.30      0.12      0.18       210
#            7       0.47      0.40      0.43       210
#
#     accuracy                           0.46      1470
#    macro avg       0.46      0.46      0.45      1470
# ...

# %% [markdown]
# ### XLM Sentence Transformer

# %%
# reading dataset
xlm_df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//xlm_vectorized_kabita_dataset.csv")

x_train,x_test,y_train,y_test = train_test_split(xlm_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=13,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    xlm_knn_model = KNeighborsClassifier(n_neighbors=x)
    xlm_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          xlm_knn_model.score(x_test,y_test))
    pred = xlm_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
xlm_knn_model = KNeighborsClassifier(n_neighbors=70)
xlm_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", xlm_knn_model.score(x_test,y_test))
pred = xlm_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
xlm_lr_model = LogisticRegression(max_iter=2000)
xlm_lr_model.fit(x_train,y_train)
xlm_lr_pred_val = xlm_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", xlm_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,xlm_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,xlm_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
xlm_gnb_model = GaussianNB()
xlm_gnb_model.fit(x_train,y_train)
xlm_gnb_pred_val = xlm_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", xlm_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,xlm_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,xlm_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
xlm_bnb_model = BernoulliNB()
xlm_bnb_model.fit(x_train,y_train)
xlm_bnb_pred_val = xlm_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", xlm_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,xlm_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,xlm_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    xlm_svm_model = svm.SVC(kernel=a_kernel)
    xlm_svm_model.fit(x_train,y_train)
    xlm_svm_pred_val = xlm_svm_model.predict(x_test)
    print("Working on SVM kernel:", a_kernel)
    print("Accuracy of SVM model is:", xlm_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,xlm_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,xlm_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    xlm_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    xlm_dt_model.fit(x_train,y_train)
    xlm_dt_pred_val = xlm_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), xlm_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,xlm_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,xlm_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    xlm_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    xlm_rf_model.fit(x_train,y_train)
    xlm_rf_pred_val = xlm_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), xlm_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,xlm_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,xlm_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
xlm_mnb_model = MultinomialNB()
xlm_mnb_model.fit(m_train,y_train)
xlm_mnb_pred_val = xlm_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", xlm_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,xlm_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,xlm_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.6632653061224489
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[160   3   0   3  28   9   7]
#  [  5 164   5   9  24   3   0]
#  [  5   6 185   4   1   7   2]
#  [ 12  22  14 123  19  16   4]
#  [ 39  19   8  11 127   3   3]
#  [ 24  18   5  33   8  64  58]
#  [  3   9   0  15   6  25 152]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.65      0.76      0.70       210
#            2       0.68      0.78      0.73       210
#            3       0.85      0.88      0.87       210
#            4       0.62      0.59      0.60       210
#            5       0.60      0.60      0.60       210
#            6       0.50      0.30      0.38       210
#            7       0.67      0.72      0.70       210
#
#     accuracy                           0.66      1470
#    macro avg       0.65      0.66      0.65      1470
# ...

# %% [markdown]
# ### XLM Fine tuned transformer Base model

# %%
# reading dataset
xlm_df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//xlm_base_finetuned_vectorized_kabita_dataset.csv")

x_train,x_test,y_train,y_test = train_test_split(xlm_df,labels_df['kabita_labels'],test_size=0.30,
                                                 random_state=13,stratify=labels_df['kabita_labels'])

print(70*"=")
# KNN
# checking the accuracies of neighbors in [3, 4, 5, 6, 7, 8] for KNN
neighbors_list = [3, 4, 5, 6, 7, 8]
for x in neighbors_list:
    xlm_knn_model = KNeighborsClassifier(n_neighbors=x)
    xlm_knn_model.fit(x_train,y_train)
    print("Accuracy of KNN model for {} neighbors is:".format(str(x)), 
          xlm_knn_model.score(x_test,y_test))
    pred = xlm_knn_model.predict(x_test)
    print("Confusion Matrix of KNN Model for {} neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
    print("Classification Report of KNN Model for {} neighbors is:\n".format(str(x)),classification_report(y_test,pred))
    print(70*"=")

# applying KNN algorithm
# taking squareroot(n) as k value. as total rows are 4900, k-value = 70
xlm_knn_model = KNeighborsClassifier(n_neighbors=70)
xlm_knn_model.fit(x_train,y_train)
print("Accuracy of KNN model for 70 neighbors is:", xlm_knn_model.score(x_test,y_test))
pred = xlm_knn_model.predict(x_test)
print("Confusion Matrix of KNN Model for 70 neighbors is:\n".format(str(x)),confusion_matrix(y_test,pred))
print("Classification Report of KNN Model for 70 neighbors is:\n".format(str(x)),classification_report(y_test,pred))
print(70*"=")

# Logistic Regression
xlm_lr_model = LogisticRegression(max_iter=2000)
xlm_lr_model.fit(x_train,y_train)
xlm_lr_pred_val = xlm_lr_model.predict(x_test)
print("Accuracy of Logistic Regression is:", xlm_lr_model.score(x_test,y_test))
print("Confusion Matrix of Logistic Regression Model is:\n",confusion_matrix(y_test,xlm_lr_pred_val))
print("Classification Report of Logistic Regression Model is:\n",classification_report(y_test,xlm_lr_pred_val))
print(70*"=")

# Gaussian Naive Bayes
xlm_gnb_model = GaussianNB()
xlm_gnb_model.fit(x_train,y_train)
xlm_gnb_pred_val = xlm_gnb_model.predict(x_test)
print("Accuracy of Gaussian Naive Bayes is:", xlm_gnb_model.score(x_test,y_test))
print("Confusion Matrix of Gaussian Naive Bayes Model is:\n",confusion_matrix(y_test,xlm_gnb_pred_val))
print("Classification Report of Gaussian Naive Bayes Model is:\n",classification_report(y_test,xlm_gnb_pred_val))
print(70*"=")

# Bernoulli Naive Bayes
xlm_bnb_model = BernoulliNB()
xlm_bnb_model.fit(x_train,y_train)
xlm_bnb_pred_val = xlm_bnb_model.predict(x_test)
print("Accuracy of Bernoulli Naive Bayes is:", xlm_bnb_model.score(x_test,y_test))
print("Confusion Matrix of Bernoulli Naive Bayes Model is:\n",confusion_matrix(y_test,xlm_bnb_pred_val))
print("Classification Report of Bernoulli Naive Bayes Model is:\n",classification_report(y_test,xlm_bnb_pred_val))
print(70*"=")

# Support Vector Machine Classifier
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for a_kernel in svm_kernels:
    xlm_svm_model = svm.SVC(kernel=a_kernel)
    xlm_svm_model.fit(x_train,y_train)
    xlm_svm_pred_val = xlm_svm_model.predict(x_test)
    print("Working on SVM kernel:", a_kernel)
    print("Accuracy of SVM model is:", xlm_svm_model.score(x_test,y_test))
    print("Confusion Matrix of SVM Model is:\n",confusion_matrix(y_test,xlm_svm_pred_val))
    print("Classification Report of SVM Model is:\n",classification_report(y_test,xlm_svm_pred_val))
    print(70*"=")

# Decision Tree Classifier
for x in range(1,21):
    xlm_dt_model = DecisionTreeClassifier(random_state=3, max_depth=x)
    xlm_dt_model.fit(x_train,y_train)
    xlm_dt_pred_val = xlm_dt_model.predict(x_test)
    print("Accuracy of Decision Tree with max_depth - {} is:".format(str(x)), xlm_dt_model.score(x_test,y_test))
    print("Confusion Matrix of Decision Tree Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,xlm_dt_pred_val))
    print("Classification Report of Decision Tree Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,xlm_dt_pred_val))
    print(70*"=")

    
# Random Forest
for x in range(1,21):
    xlm_rf_model = RandomForestClassifier(max_depth=x, random_state=3)
    xlm_rf_model.fit(x_train,y_train)
    xlm_rf_pred_val = xlm_rf_model.predict(x_test)
    print("Accuracy of Random Forest with max_depth - {} is:".format(str(x)), xlm_rf_model.score(x_test,y_test))
    print("Confusion Matrix of Random Forest Model with max_depth - {} is:\n".format(str(x)),confusion_matrix(y_test,xlm_rf_pred_val))
    print("Classification Report of Random Forest Model with max_depth - {} is:\n".format(str(x)),classification_report(y_test,xlm_rf_pred_val))
    print(70*"=")
    
# scaling using MinMax scaler
mms_scale=MinMaxScaler(feature_range=(0,10))
m_train=mms_scale.fit_transform(x_train)
m_test=mms_scale.fit_transform(x_test)
set_printoptions(precision=3)
# Multinomial Naive Bayes
xlm_mnb_model = MultinomialNB()
xlm_mnb_model.fit(m_train,y_train)
xlm_mnb_pred_val = xlm_mnb_model.predict(m_test)
print("Accuracy of Multinomial Naive Bayes is:", xlm_mnb_model.score(m_test,y_test))
print("Confusion Matrix of Multinomial Naive Bayes Model is:\n",confusion_matrix(y_test,xlm_mnb_pred_val))
print("Classification Report of Multinomial Naive Bayes Model is:\n",classification_report(y_test,xlm_mnb_pred_val))
print(70*"=")
# Out:
# ...
# Accuracy of KNN model for 3 neighbors is: 0.445578231292517
# Confusion Matrix of KNN Model for 3 neighbors is:
#  [[123   7   4  30  31  10   5]
#  [ 31 125   4  21  21   4   4]
#  [ 15  15 157  11   9   1   2]
#  [ 46  25   7  80  33   4  15]
#  [ 55  31   5  23  69   9  18]
#  [ 57  16   5  35  28  31  38]
#  [ 51  10   1  33  31  14  70]]
# Classification Report of KNN Model for 3 neighbors is:
#                precision    recall  f1-score   support
#
#            1       0.33      0.59      0.42       210
#            2       0.55      0.60      0.57       210
#            3       0.86      0.75      0.80       210
#            4       0.34      0.38      0.36       210
#            5       0.31      0.33      0.32       210
#            6       0.42      0.15      0.22       210
#            7       0.46      0.33      0.39       210
#
#     accuracy                           0.45      1470
#    macro avg       0.47      0.45      0.44      1470
# ...
