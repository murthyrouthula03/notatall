# %%
import pandas as pd
import numpy as np
import os,sys
import re
pwd = os.getcwd()

# %%
# reading dataset
kb_df = pd.read_csv(pwd+"//Datasets//Nisha//Input//Nishafin.csv", encoding_errors='ignore')
kb_df
# Out:
#                               id  \
# 0     Ugz7LQV0ZWpuNnjBaxJ4AaABAg
# 1     UgxvWJ_kJL2nePTkg2N4AaABAg
# 2     UgxxeUmiH9f8XOZZWr14AaABAg
# 3     Ugz-UPvwHMx4nSKVoCB4AaABAg
# 4     UgzfXhbesBABQzi4-m94AaABAg
# ...                          ...
# 4895  UgyGSYkiLHY3dWl4AZt4AaABAg
# 4896  Ugzx3OSiIndEsUN54IB4AaABAg
# 4897  UgxRwq2MsR9csHLc7MJ4AaABAg
# 4898  UgxxO1vtL-g7PPRVXBp4AaABAg
# 4899  UgyNWcXDvbZF1I7S8rh4AaABAg
#
#                                             commentText  Labels
# 0                              i  love potato ke prathe       2
# 1     Wwaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaww       3
# 2                                                  Nice       3
# 3                                           Wow Amazing       3
# 4                                       Thank you madam       1
# ...                                                 ...     ...
# 4895  Mam kya hum butter Ki bjaye desi ghee bhi daal...       7
# 4896  Ky hum condensed milk k jagha par amul powder ...       7
# 4897  Very yummy cake mam...condensed milk k jagah a...       5
# 4898  mad aapne powder sugar or condensed milk dono ...       7
# 4899  cake microwave oven se nikalne k baad thodi de...       7
#
# [4900 rows x 3 columns]

# %%
kb_df.shape
# Out:
# (4900, 3)

# %%
def preprocess_text(sen):
    # Removing html tags
    sentence = remove_tags(sen)

    # Remove punctuations and numbers
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)

    # Single character removal
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)

    # Removing multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)

    return sentence

# %%
TAG_RE = re.compile(r'<[^>]+>')

def remove_tags(text):
    return TAG_RE.sub('', text)

# %%
comments = []
sentences = list(kb_df['commentText'])
for sen in sentences:
    comments.append(preprocess_text(sen))

# %%
comments
# Out:
# ['i love potato ke prathe',
#  'Wwaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaww',
#  'Nice',
#  'Wow Amazing',
#  'Thank you madam',
#  'nice',
#  'Nice',
#  'Execllent women',
#  'soo kind ',
#  'I can believe she has million subs from ',
#  'Nice',
#  'thanks ',
#  'Atta flour means wheat flour ',
#  'Paratha Liked the kitchen design ',
#  'Tasty aloo paratha',
#  'Thanks Aunty ',
#  'Superb',
#  'Aunty aapne bahut hi acha aur bqhut simplicity ke saath explain kiya Aise hamare Desh me teachers ho jaye to phir kisi bacche ko tutions ki need ni ho are such inspiration And paratha is also very good healthy ',
#  'Your instructions are really useful ma am ',
#  'ur way of explaining is best aunty ji',
#  'I love this word thody se chotty thody se bady bana sakty hyn ',
#  'nisha aunty you are soooooooo humble and sweet keep it up ',
#  'Wao',
#  'thanks',
#  'Awesome',
#  'app mera bhahi hote toh bariya hota roj kuch na kuch naya khane ko milta',
#  'Nice',
#  'Hello Nisha anti mai new hun bht mazy pharahty bane muje se ap ki video dhek kr thank God muje reply kijy ga nd Maine kuch or bana hu Kia likhun',
#  'Beshk r great Blessings frm pakistan ',
#  'Madam aap thoda nail cut karo suggestion hai mera cooking karte time warna gloves wear karo',
#  'wow ',
#  'Love from Kerala',
#  'bhot Asha aalo vala prantha',
#  'Vedio bohot accha laga mam ',
#  'Nice recipe easy to cook ',
#  'Yummy yummy super yummy aaloo prathe ',
#  'mam mere potatoes ko mne boil krke cooker mein chod diye the hour after mne potatoes ko cheel ke masala banaya to masala kafi loose ho gya uske baad mne unhe choka bhi laga diya phir bhi parathe nhi bn rhe pls bataye kya kre',
#  'yummy',
#  'she is still young due to her cooking ',
#  'Very nice madam ji',
#  'Mam are highly talented and ur cooking skills are extraordinary ',
#  'Good aunty',
#  'Your voice is nice',
#  'nice',
#  'You explain very clearly and sweetly ma am Thank you',
#  'Mam jab paratha belte hai tao sara masala corner pe aa jata center me kuch nhi rahta',
#  'Also paratha receipe nice very nice ',
#  'Nisha mam tried it it was too good make parathas dis way for my kids once in week dey enjoy it showed very awesome recipe God bless n ur loved ones ',
#  'Thanks mam It very easy and yummy',
#  'Wow wow wow mouth watering',
#  'My mom is not here so wanted to make aloo ka paratha and this vid helped me thanks',
#  'Madam oil ka place ghee use kar sakthe he kya',
#  'Very delicious ',
#  'very good and nice recipe mam',
#  'Thanks aap itna Achha paratha Banai hai aur aap bahut acchi hai thanks',
#  'Itna oil ',
#  'Osm pratha aunty ji',
#  'Who try this please one like',
#  'Wow apke parathe kitte kitte mast wow mughe to abi khane ka mn kr rhe mae bi aj hi bnaungi',
#  'Thank you ',
#  'Ma am really your all recipes are testy m ur big fan this paratha recipe also very nice ',
#  'Majedar bana hai Aloo paratha ',
#  'M newly mrd dono anythng to cook my hubby lyks alu paratha tqsm mam fr dis recipe ',
#  'Nyc',
#  'This women is very good',
#  'Very good pratha ji',
#  'Thanku mam',
#  'Very very nice holiday cook my grandson im also cooking expert in all once again wish you',
#  'Thank you mam bht testy hai ',
#  'Nice bhabi ji',
#  'Mam AAP bahut ache tarike se sikhati thanks',
#  'Thanku so much',
#  'I am trying early morning',
#  'Nice Aunty ji',
#  'Thank you tried it It is very tasty',
#  'Thanks mummy ji ',
#  'auntie its me again THE JOKERfrom kashmir and wanted to ask that can we use gram flour besan instead of wheat flour maida ',
#  'Very nice parathe',
#  'Super mam',
#  'koi new recipe dijiye Nisha ji',
#  'Thanks ',
#  'Yummmmmmy ma abi try krny lgii hu',
#  'Nice recipe aap ka andaz itna pyara he samjhane ka ke kia hi baat he thanks for the recipe',
#  'Very yammyyyyyyyyyyyyyyyy',
#  'Really nice Paratha ',
#  'I will try',
#  'MarshAllah beautiful excellent parathay',
#  'Mam koi bhi stuffed paratha bnati hu to sari stuffing kinaro aa jati or beech sirf aata reh jata To kya kru ki stuffing pure parathe evenly lg jaye',
#  'aaj to me bhi ese try karugi mujhe to aloo ke parathe banana aate hi nhi the thank you so much mam',
#  'Very very nice thank you for sharing ',
#  'Superb aunty ji aapse bahut sikhne ko milta hai ab main bhi aapke wajah se ache paranthe banane legi hoon thankyou aunty ji',
#  'Great thanks lot for the yummy parathas',
#  'V nice',
#  'Thank you Ma trying your parathas today once succeed ll reply to my post ',
#  'So tasty and you are also so sweet aunty',
#  'Superb mam',
#  'Badhia mam Apka express karne ka tarikese Kavi bour Nehi Hoti Ap bahat ache ho mam Pyarse patience ke saath samjhati he ',
#  'Wow thanks u',
#  'Very good tastie bhi healthy bhi',
#  'Mai KAL banaungi aaloo ke parathe',
#  'Muje bas aap pasand ho ',
#  'really so tasty ',
#  'really lovely',
#  'Apko dekh ma ki yad aa jati h',
#  'Nice recipe mam love you',
#  'nice',
#  'Happy new year aanti',
#  'Madam We shall not pour the oil first in the pan Because if we put parantha over the oil it will splash ',
#  'Wahi Yammy yammy',
#  'Tsty parathaparath ',
#  'Nice yummy ',
#  'thank you so much',
#  'Wow',
#  'This is amazing tried it tasty',
#  'Yummy',
#  'Nice',
#  'Bot ganda',
#  'Kya Partha',
#  'Very nice ',
#  'Apki awaj jaan nikal leti bahut khub samghati cute',
#  'Nisha Madhulika top women',
#  'Wwoooww',
#  'Aunty you are too good and very talented ',
#  'Nice',
#  'Thank you Mrs Singh showed me how to make them when was in Kolkata But this is really helpful ',
#  ' so easy recipe trying to home thank you ',
#  'nice ',
#  'Lovely Paratha by lovely woman Love from Pakistan ',
#  'Today eate paratha my friends are from india theyre make for me loved',
#  'Aapki hr recipe must rehti h',
#  'Aunty very yummy aloo Paratha ',
#  'Mam love the way narrate your voice is very sweet way of talking is very calm ',
#  'Very testi',
#  'Thanks mam',
#  'so nice the way you make it Aunty',
#  'Nice mam',
#  'Garlic dalte to orr bhi tasty banta',
#  'Very testy',
#  'Nisha jee you best chef REALLY like frm PAKISTAN ',
#  'Tasty',
#  'Mam hamare parathe fat jate kya kare ki fate nhi',
#  'very nice',
#  'Wow it amazing to learn parathas recipie',
#  'aloo ke parathe mujhe bahut bahut pasand hai aap mujhe bhej do na',
#  'Hi Nisha mam please make any paratha curry recipes As early as possible ',
#  'Ma am aloo fry krke to parathe banate hai plz uski recipe bhi share kariye',
#  'Aunty ji khane ka man Kiya ',
#  'Thank Mam ',
#  'Nice paratha sooo yummy Explain Karne ka tharikha hohat acha he Superb',
#  'Very very nice paratha',
#  'Most welcome mam',
#  'Kuch dikh nhi raha',
#  'wow mam kya aapne parthe banaye hai ',
#  'Nice',
#  'Awww she seems like such sweet lady had to subscribed ',
#  'Mam you are so intelligent and your all video is so good',
#  'Bohot bohot shukriya aunty jee aapka pyar se batane ka tarika bhi bohot acha hai ',
#  'Hi Nishaji love ur videos d way explain loads of love keep helping us in cooking variety of dishes tried Aloo paratha turned out very yummy thanks lot',
#  'Pata nahi kyo Lekin jab bhi aapki video dekhta hu eaisa feel hota hai meri maa mujhe samjha Rahi hai thanks lot Your voice is too attractive',
#  'Thank you aunty ',
#  'Brilliant ma and Yummy ',
#  'Nisha ji aap bhut acchi trhan explain karte ho Nice reciepe ',
#  'I really like ur all videos Inspired by And ill try most of ur recipes love for mam respect for you',
#  'I tried ur all recipe they came super thank so much learnt many dishes from please finger papad ingredients and it making post ur coming video please',
#  'Very nice paratha',
#  'Wahhhh aunty kya banaya Paratha tasty lajawaab muh me Pani aa Gaya kya bolu me kash ye Paratha bahar aa Jata me banaungi aaj hi nahi Raha jayega ',
#  'I like all ur recipes m also trying at my home love Maam shahina frm New Zealand',
#  'So tasty aunty ',
#  'She is very talented Thanks alot mam ',
#  'Tadka lga kr BHI hum stuffing bna sacte h',
#  'Very nice mam bahut hi acche bataya aapne thanks',
#  'mam like the way cook easy great taste ',
#  'Mam aap kon sa tail use krte hai pranthe banane ke liye',
#  'Kuch new racipe batoo na nisha ji am big fan my ap ke raspice try karte bhoot accha banta samosa aloo ke takie allmost cooking nisha ji imran khan my hasband for city nagpur',
#  'Alu hre hai ',
#  'Waoo mam Very teasty me jarur try krungi Thanku mam',
#  'Thnx for this all favourite recipe ',
#  'Nice',
#  'Super madam watch smusic vaibhav be puja in Marathi',
#  'Super mam',
#  'Nisha ji ke raspice bhoot pasand aate hai love cooking for Nisha ji my name is mrs nusrath khan from nagpur city',
#  'You are so sweet',
#  'You have done the most difficult receipe in easy way awesome ',
#  'Mam as usual vvv nicy recipe love alu paratha ',
#  'Ur explainations are so clear love ur videos Mam ',
#  'I would say Thank you mam for all good cooking ',
#  'Whenever want to cook something only search your youtube channel because first reason your voice is very nice which dnt irritates me like others youtubers channels and second the way you teach your cooking it make me feel very easy to learn ',
#  ' aaloo pratha ',
#  'Tasty',
#  'Theek eshe hi banaugi ',
#  'Good method thanks mam',
#  'Very very nice paratha',
#  'please mam share some diet food receipes',
#  'Bahut Achhe bne mere prathe',
#  'Hello mam love you so much ',
#  'wow very testy yummy yummy Thanku mam will try',
#  'Thanks mam are so sweet lovely ',
#  'Yummy paratha ',
#  'Very nice',
#  'Super',
#  'I wanted to ask question but always thought it was not appropriate but couldn resist today want to ask whether do you use dishwasher for cleaning your utensils Coz most of them look new ',
#  'Aap samjhane ka tarika bhut acha h',
#  'Wah nisha aunty love frm pakistan ',
#  'Very testi ',
#  'Love nd ur recipies aunty',
#  'Very nice Aunty',
#  'Mam your recipes too good and cooking way is so easy Aapki help se b kitchen me bahut Kuchh bnane lgi hu Thank you so much mam m your biggest fan ',
#  'This looks so yummy',
#  'Super super',
#  'excellent mam thank you very much ',
#  'Thank you mam for this nice recipe',
#  'Ak to tumhari neck itni hil rahi hoti hai mera dheyan tumhari neck he hota hai',
#  'Kya him aate or sabhi aalo masalo koo mix kr skte kya plz reply plzzzzzzzzzzzzzzzzzzzzzz',
#  'Bohat tasty Dikh rahahe mean fantastic ',
#  'she is so sweet ',
#  'thnx mam aap to reply karne me bhi bahut fast ho',
#  'kya mam garam masala use kar skte ',
#  'hi Kya hum all purpose flour use kar sakte hai ',
#  'Wow soo taste ',
#  'Nice',
#  'nice',
#  'Madam explain very softly and sweetly like ur paratha',
#  'Hello mam aapka har recipe bahut testi hota Apka har recipe follow krti hu Mere husband toh bahut khush ho jaate mere se so thank you mam',
#  'Super Auntie',
#  'nice',
#  'Nice',
#  'Very well explained wish can cook like her',
#  'M aapke hr video dekhti hu aap bhut ache ho',
#  'very very very tasty',
#  'One like for this talented Anty ',
#  'Nice made Anty ',
#  'Buhat acha sikhati hayn',
#  'bahut tasty bahut mast tha ghar me sbko bahut bahut pasand aaya bahut tasty tha ',
#  'Thanks aunty for this recepie ',
#  'bahot bhadiya bana mam',
#  'Thank you',
#  'Waooo it so yummy my mouth is watering ',
#  'Aap mujhe bhot achi lagti hain bhot meetha bolti hain aap aur apki recipes jabse apka channel bana tabse dekhrahi hun or itna kuch seekha aapse God bless you ',
#  'maam so sweet',
#  'thanks mam',
#  'I lv ur smile nd voice mam Lv alot ',
#  'Mama mia',
#  'Super tq',
#  'Aap etne acche kaise bol lete hain aap ki presentation se hamara dil paratha se vi bhar gaye hain unty thank ',
#  'tnx nisha madulika',
#  'm ne kal ye parata banaya ta to buht hi yummy bana ta',
#  'you are the best chef ',
#  'it was yummmmmmmmmmmmmmmmmmmmmm ',
#  'it was last modified to the method',
#  'thank you one with English subtitles looks very nice ',
#  'Hmmmm looks yummi',
#  'Nice',
#  'Can we grate the potatoes mam ',
#  'Humain be bajie Nisha madhulika',
#  'This is so tasty ',
#  'Thanks lot mam ',
#  'Thank mam',
#  'Aapki btae recipes simpal aur bohat jada testy hoti hai ',
#  'Wow mam amazing yummy love from Kashmir ',
#  ' Very Nice Mam ',
#  'App mam ho',
#  'Its Really amazing Awesome Superrbbb mne avi just ye recipe follow krke bnaya its really too tasty Amazing Thanks lot maam ',
#  'Thanks',
#  'Why dislike ',
#  'Nice mam',
#  'It very nice',
#  'U awesome mam jab kch bnana hota sbse phle apki recipe hi search krti hu',
#  'Mehrbani aba',
#  'Very Nice',
#  ' inhe bhee chalaatee beech bharke banaa sakte hai madam Ji ',
#  'Nice one mam ',
#  'i respect every all mother',
#  'Aapki har recepie mujhe aacha lagti nisha aur main baat to ye ki aap bhot bariki tarika se samjhati wo aur jyada aacha lagta You so cute ',
#  'Nice and tasty',
#  'thanks mam ',
#  'Bhai kon lucky wo jiski mummy h',
#  'aapne bahut acche se smjhaya thanks mam',
#  'thank you mam ',
#  'Very nice',
#  'I finally made it yaayyyyyy Thank you mam Loved it Yummy',
#  'Thank you so much',
#  'Yummy',
#  'Wow nice mam ',
#  'Kya stafing me Magi masala dal sakte he',
#  'I am from Goa aunty love the way explains how to make parotha Love aunty ',
#  'Hii aunty kya ham ginger aur mango powder ke bina nahi banasakte kya',
#  'aanti aap bhut aucha resapi bante ho ',
#  'Love mam ',
#  'Beautiful kitchen wowwwwwwwwwwwwwwwwww have never seen such beautiful kitchen',
#  'Thank you ma am just made it and ate it So yummy ',
#  'Ap bahut sweet bolte ho ji',
#  'Yor all recipes are great',
#  'Super aunty maja aa gya easy or aacha partaha',
#  'very nice anti ji',
#  'Thank you mam parathe ekdm zabardust',
#  'God bless you',
#  'anti bahot door hn nhn to mn ap pas zaroor khanay ko at ',
#  'mera aalu paratha fat kyu jata he masal bhar nikl jata he',
#  'love the way you teach',
#  'Very yummy',
#  'Very yummy',
#  'Nice',
#  'You are best chef',
#  'you great',
#  'Mere aloo ke parathe full Jaate Hain aisa kya kru Jis Se paratha na Pate',
#  'I used this recipe for making parathas for my mothers birthday She loved them Thank you for this wonderful video ',
#  'Nice',
#  'Nyc mem',
#  'Mam aap bahut acchii tarah se samjhaate hoo har recepie ko acche se samjh aati sabhi recepies thanku so much mam itni acchi acchi recepies ki video banane liye ',
#  'Ma am isme aloo sath pyaz ka use nahi kar skte hai kua',
#  'Thanq Nisha madhulika ji tried them mere parathe bahut ache ayye with ghee there so yummyy',
#  'Nice video',
#  'It awesome recipe also made its when feel hungry and very lazy ',
#  'Damn girl your famous',
#  'Thank you for putting subtitles on this video will definitely be trying this recipe m glad you shared such an amazing recipe with all of us ',
#  'nice mam ji',
#  'nice',
#  'to much nice mam yummy',
#  'Looks very tasty ',
#  'Mam Mai jb bi Alo paratha banati hu to paratha fat jata na Alo Bahar niklne lgta kbi kbi kbi achhe se ban jata h',
#  'Nyc anty Iove your voice',
#  'Just awesome mamm ',
#  'Mam mere pranthe mein aaloo evenly nhi aata my husband says kai kai jagah pranthe mein aaloo nhi hota',
#  'Nice mam',
#  'Nice',
#  'Very very tasty ma am',
#  'My experience was amazing my little brothers and sisters very happy while eating ',
#  'Tasty recipe mam so delicious',
#  'The recipe was so easy will try making it today for the first time Thank you for sharing this recipe ',
#  'So nicely explained and adore the passion with which you say each word Hats off Nisha ma am ',
#  'soo nice mam',
#  'Very nice recipe',
#  'Meri mamiy ne banaye bahut tasty bane h',
#  'Very Nice janab',
#  'aapne bahut achha Banaya Hai super mame',
#  'mam ap mom jese ho bilkul',
#  'Very taste prantha mam',
#  'Nice parantha eat',
#  'Osm recipe aalu Pratha is my favourite',
#  'Madam kya aap Pakistani Ho',
#  'Super maaji ',
#  'Very talented women cutee too nicely explained ',
#  'fantastic',
#  'Nice paratha mam',
#  'I tried it but my stuffing is getting out when make the paratha why ',
#  'osummmmm and yummy recipe',
#  'kashala kelis',
#  'Really appreciate that love from Turkey',
#  'Very nice',
#  'Nice',
#  'Looking tasty ',
#  'o so every time make them the stuffing just bleeds thru will try for the th time again',
#  'Very nice ',
#  'Thanks aunty Very cute way of explaining ',
#  'Very nice pratha mem',
#  'Very nice mam and you explain so good',
#  'Hi how are you Please one day also publish how to prepare chicken chillied or mutton korma please',
#  'Mera aloo ka paratha fat Jata Hai stuffing Puri bahar nikal jati hai kya karna chahiye',
#  'Waww wasome',
#  'Very nice',
#  'Iam your big fan mam lots of love from dubai',
#  'Nisha mam your recipe are such great recipe in the world very tasty recipe',
#  'Tooo good nice explaination',
#  'Very tasty aap aloo ka paratha banati ho ',
#  'Wow Nisha ma am Apki recipes Ghar ki yaad dila dete Nice recipe ',
#  'Very nice wow',
#  'Love allo Ka partha Love you from pakistan',
#  'Aunty r so sweet nd lovely nd love ur recipe',
#  'Sooooo yummy ',
#  'Thank soo much Love from Bangladesh',
#  'Nisha ji aap ki cooking mjhy bht pasand hy ',
#  'She explains so well Love you mam You are soooo cute ',
#  'aloo Paratha',
#  'mam ap Aur ap ki recipe duno lajawab h',
#  'dayum gotta try this looks delish ',
#  'Love you aunty',
#  'Woooooooooooooooooo',
#  'Nani very nice',
#  'Nice one ma am have question Pratha low ya high kaise flame pr sekna chahiye ',
#  'Thakuuu soo mch mam r such talented',
#  'thank mam',
#  'Aap bahut ache Se samghaya thanks',
#  'Nice',
#  'Nice recipe',
#  'very good',
#  'Mei bhi hr baaar aise hi prathe bnati hu Jo ki mujhe aapne sikhae unty ',
#  'thanks mem',
#  'Nice mam',
#  'Madam you are doing very well keep going with new more recipes Thanks for your kind information ',
#  'very nice pratha ',
#  'yeh bohot aasan reciepie hai maine bohot dino se banaye nahi hai aj apki recipe dekh ke me banaugi ise kal thanks mam ',
#  'I tried this and trust me it was soooo yummy ',
#  'Thanku auntie mujh aap ki rashpi achi lagh ti ',
#  'wowwwwwwwww Nisha jii ',
#  'Nice ',
#  'Wow try to Make it today and my husband loved it ',
#  'Very nice guider',
#  'Thank you very much loved it',
#  'Thanks loved it ',
#  'You are very nice man or apki recipe bhi supper h',
#  'Nishji ki recipe always best',
#  'aapko mai apni maa manti hu maine aap se hi pura khana banana sikha hai thank so mch God bless you ',
#  'Nisha ji aap ki her recipe suopr het he ',
#  'Mam like Ur explaining style',
#  'Nice paratha',
#  'lovely',
#  'so tasty',
#  'Wow nice recipe',
#  'Samjhate bohot atche ho aap receipy ko',
#  'thenku Mem',
#  'Very nice ',
#  'aamchur pawder nahi ho to kya dal sakate hai ',
#  'Mam hamane Aj hi banake dekha bahut hi achaa tha Really mam so nice paratha love it Mam ',
#  'Thanku Mam am very glad that saw this video highly appreciated Nd well explained make my day hv tried this in ur style it is amazing ',
#  'Aap Ki Har recipe both achi hoti hai aur easily bana de sakte hain',
#  'Nice mam love it ',
#  'Thank mam Maine pahli bar banaya bhut acha bna thank soooooo much',
#  'Thank you mam on the behalf of my mum and from the bottom of my heart',
#  'Mam aapki aloo ke parathe ki recipe bahut achhi thank you for sharing this recipe ',
#  'Nyyccc',
#  'OK thanks mam',
#  'Very Nice Aaloo Parathe Nisha Madhulika',
#  'Looks delicious m going to make them today',
#  'Nisha ji aap ko bohot bohot dhanyavaad Aap Se seekhi hui har ek recipe Se banai huyi khana hamesha super hit hoti hai thank you so much ',
#  'Mughe issme carrier banana h',
#  'Nice pratha mam Yummy',
#  'Mughe khana bana baut jada accha lagta h',
#  'Mam mughe apki help chiye',
#  'So yammy',
#  'Good mam ',
#  'nice',
#  'yummy',
#  'you ara very best chef',
#  'Very nice',
#  'I like ur each and every recepie made by u',
#  'Thanks mam',
#  'Hum Dekhte hi bhook Lag Gayi man kar raha hai abhi hi Toot Pado thank you very very much nishamadhulikji thank you thank you thank you thank you so much love you',
#  'Very nice',
#  ' thank you Such Simple Video Mine Came Out fair to Fine but taste great ty',
#  'Bhtut acha samjhati hai aap mam',
#  'Explaination super thank you so much mam',
#  'aapne aache se explain kiya thank u',
#  'tq nisha jii',
#  'I wish could eat these parathas online',
#  'Good',
#  'mem agr alu pani chod jayee or ptle ho jayee to kya kre',
#  'aloo paratha super',
#  'Aaj aalu parathe bnaye or aapke recipe according Ymmmy schi',
#  'nice',
#  'Nice',
#  'wow mam ',
#  'Can we skip dry mango powder and green chillies ',
#  'Im trying this today st time',
#  'v nyc pratha',
#  'Nice',
#  'Nisha ji kya hum aloo ki stuffing ko fry karke bhi bana sakte hain ',
#  'She lovely',
#  'I don have amchur powder can use lemon instead of that',
#  'Beautiful Real mothers hand ',
#  'Very nice Mam bhot testy bne Pathe',
#  'nice and tasty ',
#  'hiii ma am',
#  'Mam mere paratha lines aa jati h',
#  'Nisha ji can please make stuffed egg parathas in delhi style ',
#  'I always love you because when see you feels like r my family member r so sweet ',
#  'Your KITCHEN is amazing ',
#  'Good job aunty',
#  'shabash aagay bado ',
#  'Thank you aunty for help in my project',
#  'Salute to all talented chef present in entire Indian home Perfect round parathas easily made',
#  'ooo wao tasty paratha',
#  'Thanks ',
#  'Madam mera har bar paratha bele ne se pura fata jati he isske liye kya karen',
#  'It delicious wud try when here is rainy weather ',
#  'Thanks nisha tayi',
#  'Ap samjate bhut bhadiya nice',
#  'Very nice mam',
#  'Very nice',
#  'Mam very nice paratha mene aaj try kiya',
#  'Good afternoon ma am very nice recipe ll try this and hope my kids would like it ',
#  'Nice g',
#  'Yummy ',
#  'Nisha ji yamy',
#  'You have not use onions in any recipes',
#  'Thanx mam love you',
#  'So nice mam thanks for sharing the recipe of aloo paratha ',
#  'Jitni achchi aapki recipes banti hai utni hi pyari Aap hai aap muze apni didi si pyari lagti hai Aap itne pyar Se batati hai ki har recipes achchi banti hai hamse Love ',
#  'Nisha ji whenever make paratha the stuffing goes on sides middle part gets empty why so hv tried in many ways but the same problem occurs',
#  'best',
#  'Thanks Mom',
#  'Very nice and tasty ',
#  'Mem muje apka har recepi bhohat axa lgta hai mene aapka do recepi banai hai or shobko bohat axi lge thank you mem',
#  'Waaooo so yammmy mam love it ',
#  'Thanks Nishaji for sharing followed the best aloo parathas in my life today ',
#  'Thank you for giving every details',
#  'Aap bahut achi baatein karte hai Thank you aunty',
#  'nice',
#  ' Thanx',
#  'Best recipe',
#  'Had tried to make aloo paratha many times but never got it right But your way was so easy to understand and prepare And it was so yummy Thank you so much am God bless ',
#  'Ooh so yaaameee',
#  'Aunty maja aa gaya banake khake aaya comment likne Videsh se dhanyawaad ',
#  'Awsome madam ',
#  'mam please mirchi ka paratha',
#  'Mam Just love ',
#  'Mam you explain Receipe so beautiful that any body can cook m trying this recipe now Potato has not boiled yet Well thank you for this ',
#  'Such an easy turorial with lot of tips too and looks delicious ',
#  'very naice masa alla allo parata thank for racepi sering to me love u',
#  'thanks antiji ',
#  'nice paraths Mam',
#  'Very nice Pratha',
#  'Hi just made allu paratha with your recipe today and it turned out great ',
#  'kashturi methi aata guthte samay daal sakte hai kya mam ',
#  'Thank you ',
#  'Very NYC mam',
#  'Thxs mam',
#  'Your resipies are best hi di yai',
#  'Tasty',
#  'i will not give coriander and chillies',
#  'Miss aap bahut ache se samajate ho ',
#  'Great',
#  'Wow mam apne boht ache se samjhaya ma aj hi bnaugi ap boht sweet ho ',
#  'Best love your cooking madam',
#  'very nice video',
#  'Thanks lot for shearing my favorite paratha',
#  'Can you use besan or gram flour',
#  'Very good madm',
#  'I love your receipe just made it and it turned out amazing ',
#  'Nisha ma am r very sweet explain very nicely just loved it recipe',
#  'Thank you mam ek aur request thi mam baccho ke tiffin ke liye koi asaan si resipe btaiye jo asaani se jhat pat ban jaye aur taste and healthy ho',
#  'U my mentor Nisha Ma am Happy mother day to My husband loved the parathas which learnt from Thank so much ma am Love to see all ur videos ',
#  'Hum aaj hi try karenge',
#  'me to fan hogaya assa haa',
#  'Superb',
#  'Thank you so much for this ',
#  'One of my favorite Thanks ',
#  'very nice mam maine try kiya bahut acha bana thank you',
#  'Thanku ',
#  'So taste year',
#  ' ma am aap baut cute ho Ek dum advice for life de di apnay ',
#  'Nice',
#  'Bhook lag gaya',
#  'i love your voice dd ',
#  'Aunty kabhi khila bhi dijiye r great',
#  'So good ',
#  'Nyc',
#  'Very nice mam',
#  'Nice information',
#  'Very very tasty mam thanks for sharing this method ',
#  'Super aunty',
#  'wow',
#  'thanks unty',
#  'mam only dahi ke saath paratha accha lagega ya dahi me bhi kuch milana hai ',
#  'Nisha ji plz malai paratha banana bataiye',
#  'lvu maaji ',
#  'Very nice mam ',
#  'thanks mam it my favourite dish',
#  'Masha Allah Ma am today am try this recipe It so yammy and tasty Thanks allot for sharing us new recipe Thank you so much ma am ',
#  'Mam r the best Loved it soo much ',
#  'nice',
#  'Thanks for sharing good recipe ',
#  'Hello Ma am You must be very much loved by your children You speek so sweetly Your children are so lucky to have mother like you With lot of respect Raja',
#  'Nice',
#  'I like potato paratha',
#  'Wow',
#  'nice',
#  'i love that my favorite food ',
#  'please tell me the recipe of pyaj ke oarathe',
#  'good',
#  ' yummy paranthas ',
#  'Dear ma am you are extra sweet ',
#  'mam mere aloo toh andar se sukhe the mere yaha pasand ni aaye mem or kya kr sakte kya aloo spicy ho jaye',
#  'Nice video',
#  'super sister',
#  'Hey thanks for sharing Mam made aloo paratha first time and my family loved it Thanks ',
#  'Nice mam',
#  'i used to loove these when lived in India',
#  'Super mam',
#  'Very nice',
#  'I seriously loved the way represented the food and are allways smilling ',
#  'me aapka bht bada fan hu your reciepe is always best',
#  'very nice',
#  'Very nice recipe Going and try it soon',
#  'nisha ji Ki recipi dekhne valo se anurodh he plg unhe laik na kre to dislaik bhi na kre',
#  'good morning Mem apki har recipi mujhe bhut acchi lagti he me apki har recipi ko laik karti hu mujhe barha accha lgta he qyoki ap sabkuch Hindi me btati he mujhe jyada English nhi ati',
#  'I love the way you talk and explain really want to learn aloo paratha Ill follow your recipe Finger crossed',
#  'Thanks madam',
#  'Really very tasty aaloo fraitha ',
#  'Thanks for teaching me aalu paratha',
#  'very nice',
#  'bhuka marengey aap thank you ',
#  'You are awesome Muh mai paani aa gya',
#  'Superb parota Yummy yummy',
#  'Can we use maida instead of gehu ka aatha',
#  'Me Pehli Baar Aloo Ka paratha Bana Raha Hoon Just Bcoz Ghar pr koi Nahi Hai Me Bahut Mushkil samajhta Tha But Mam Aapna Itne Ache tareeke Se Bataya Hai Thnks You Very Much Mam ',
#  'Thanks lot maam for this delicious recipe',
#  'aunty aap bohot sweet ho or axhe se samjhate ho',
#  'Thank you so much',
#  'Kya hm is aloo ke stuffing ko rat me ready kr ke rakh sakte subha ke nasta ke lye',
#  'yek dum accha hai',
#  'mam muh mein paani aagaya but can surely say thait my naani make aloo parantha just like you',
#  'thank so much nishaji today made parotha it was really tasty thank ssooo much ',
#  'Very nice video and voice also very nice and like it',
#  'Garmi ke dino ke liye kuch recipe',
#  'Thanks ',
#  'That looks yummmmmyyy',
#  'You are the best auntie Thanks so much ',
#  'Thanks for replay nishaji',
#  'Superrrr',
#  'Amchur powder ki jagah kuch aur use kar sakte hai kya ',
#  'nice aunty',
#  'U the best aunty',
#  'my too fev aaloo paratha',
#  'wah anty kmal krdiya',
#  'tq for parata supper ',
#  'Well done Nissan ji',
#  'U an awesome cook Agar mhe aapki ghar ke paas ek ghar rent lelethihoon then aap video keliye jo kuch bi recipes banathe ho aap befhijar mujhe taste karne keliye dhe dhena mhe no kabhi bhi nahi kahoongi ',
#  'Very nice mam love your recipe ',
#  'Thanks its very easyy',
#  'ToO good ',
#  'Thnks ',
#  'Very test paratha',
#  'it is very nice parata thank u',
#  'bht shukria teps denay ka or indian logo ka urdu ',
#  'Uuuuu yummy paratha ',
#  'now my mouth is filled with my salaiva',
#  'bohot khub aap aap ka method bhi bohot acha I like mam very much',
#  'Thank you very much mam like all your videos have also tried some recipes they turned out really nice you are very sweet cute mam it feels like my mother is explaining me teaching me cooking you are the best whenever want to cook something always see your videos the detail explanation which you provide with logical reasoning about technique ingredients gas power is so impressive anyone can learn cooking from your videos plus your motherly love personality is so caring feels like my mother is standing their Long Live Nishaji Mam God Bless You',
#  'very nice',
#  'Yummy thanks for aloo paratha ',
#  'tasty paratha',
#  'Very tasty',
#  'Thank you Ma am for the great recipe Love the way you explain and talk just like Mom ',
#  'Ma am Thank You so much yeh receipe to main khud bhi bana sakta hun m years old bahut hi aasan kar diya aapne to Again Thank You So Much ',
#  'delicious',
#  'very nice',
#  'speek sorry you are cute bye the way',
#  'you sleek like mom',
#  'I just cooked it wonderful recipe ',
#  'Veryyyyyyyy nice',
#  'Kya main iss stuffing ko store kar sakti hu ',
#  'Amazing mam r my inspiration my cooking teacher ',
#  'Thanks for providing info',
#  'Thanks Maine aap ke style mein Parathe banaye aur bohot tasty bane ',
#  'Thanks for uploading this this helps me so much',
#  'lyk her voice',
#  'WOW IT AMAZING AND EASY RECIPE THANK YOU SO MUCH MAM ',
#  'Thank you so much mam ',
#  'very nice yummmmmmyyy anb like it',
#  'Very very tasty receipe',
#  'Thank you',
#  'thanku soo much ma am r gem thanku ',
#  'Tasty',
#  'Kabli chane sukhe kase banain nisha madulika je',
#  'i lyk ur recipes',
#  'I am hungry',
#  'Yummy',
#  'Thnx lot mam',
#  'Nice mam',
#  'I jus Luv Nisha Madhulika videos She explains everything finely ',
#  'thanks mam love aloo paraathe',
#  'wonderful parata will make it today ',
#  'Great recipe thanks for sharing',
#  'mam nice yummy ',
#  'Very nice',
#  'Mam r so sweet thanks mam',
#  'Love your pataro parata recipe and have Tried it ',
#  'NICE ',
#  'Thanku so much for the reply Nisha aunty will try the same recipe again',
#  'very very nice parata',
#  'Can we use chaat and garam masalain aloo paratha ',
#  'Thank you aunty ',
#  'Kya ho gaya inko kha kar icu jana kya',
#  'WOW NICE',
#  'mam aapka tv par vi add ata hai na nisha madhulika g',
#  'I just made amazing aloo ka paratha with your recipe thanks so much ',
#  'You are so cute smjhany ka andaz boht acha hey ',
#  'very nice',
#  'men ap ke recipe bahot achhe hai',
#  'good recipe like recipe',
#  'Nisha mam aap Jain ho Kya aapki recipes me aapko kabhi onions and garlic use karte nhi dekha',
#  'mam ap in parathaon liye aur aate liye konsa oil use karti h',
#  'Tasty',
#  'Nice',
#  'Nice recipe',
#  'Thank you Ji am from Kerala and have cooked aloo paratha today for the first time in my life It so good and so yummy thanks lot for this easy and simple authentic recipe',
#  'Nisha Ji laundo ki life set krdi aapne ab hamare Ghar pe bhi khana banta hai Bachelors ',
#  'Ma am love you ap bohot ache se sikhate ho ',
#  'Thank you nisha mem ',
#  'I love this video',
#  'Yummy thnx vdo',
#  'Vry nice',
#  'Very useful tips deti ho Aap thank you love u',
#  'Very nice aloo paratha',
#  'Yummmmmmmmmmmmmmm ',
#  'thank fr recipes finally made it today with help of dis video it was become really tasty thank so much ',
#  'Thanks alot for ur receipe tried it',
#  'All the best nishaji',
#  'Nishaji Thanks',
#  'Thanks ',
#  'Very good nishaji',
#  'Nice the best one',
#  'Thanks for the shering video ',
#  'ap bht achi hain bht acha bolti hain me ny subscribe kr liyaa ap channel ko ',
#  'bhut Hi achi recipe h',
#  'I made it yesterday such an easy way to make Thanks lot now don gave any problem to make ',
#  'Your voice is beautiful mashallah',
#  'I love aalo paratha ',
#  'Thanks',
#  'bahut yummy tha ',
#  'Mam potato ko cooker mein kitne seeti aane tak boil karne ka ',
#  'Hi Nishaji my five years old daughter Jannhvi is big fan of yours She eats love only food cooked by Hum log ghar par apke recipe se hi khana banate hai ',
#  'mem you are so cute',
#  'I made this today it was sooo yummy but added onion ij it as well which tasted sooooo good ',
#  'Men aap mujhe bhot acche lgte ho aapke bolne ka andaz bhot accha hai aapko dekhkr mummy ki yaad as jati hai',
#  'I a Kashmiri and Aloo Ke Parathe are not in our culture But of late tea stalls etc have started to serve them and we have developed the liking for them However they don add the ingredients you do neither are they cooked cleanly On the contrary your Aloo Ke Parathe consisted lot of ingredients and you cooked them in healthy way Now can wait to cook Aloo Ke Parathe at my home whenever can Thank you and love from Kashmir ',
#  'nice',
#  'I make it It was very easy and tasty Jst love it Thanks for sharing recipe ',
#  'Nice mam',
#  'I just love your voice the way uh speak like child ',
#  'nice paratha',
#  'taste',
#  'Kya hum alu parathe ke mix me maggie masala daal sakte hai ',
#  'Nice receipe mam love your all recipes',
#  'Yum yum',
#  'I saw so many aaloo paratha recipe including Sanjeev kapoor but love the way detailed out the instructions thank u',
#  'Yummy Pratha Thanks for Sharing ',
#  'v nice mam',
#  'mam parthe sepuan nikalta he',
#  'mam ab bhot ace se samjate ap muje bhot ace lagte mam ',
#  'Thankiu mam ',
#  'mujhe belna nahi aata ',
#  'Yummmmmmm Tasty hai ',
#  'Liked your simple clear presentation and tips given Will definitely try to make it ',
#  'Salam Nice recipe Subscribed when saw the parathas ',
#  'Wow ',
#  'Nice Aunty ji kaun se oil ka use karna hoga ',
#  'thank you so much',
#  'good',
#  'M trying this right now',
#  'Nisha are your best cook love it',
#  'Ymmmme ',
#  'Nice',
#  'Awesome thankyou so so much GOD BLESS YOU',
#  'superb ',
#  'Thanks aunty jiii Love alots',
#  'wow ',
#  'Nice',
#  'good',
#  'Ty mam ',
#  'Mam tikki banana sikh do please',
#  'nice',
#  'thanks you anuty for this taste recipe love it ',
#  'thank you so much and really appreciate',
#  'You are the best ',
#  'isko dekh kar mujhe bhook lag rahe hain',
#  'thanks allot for sharing this with us mam',
#  'wow is video se mai ne sahi stuffing method sikha thank you so much mam ',
#  'You have not cooked the aloo stuffing this wrong method We should not use stuffing without cooking it is not good for our health',
#  'this is favorite food ',
#  'very good',
#  'Wow mam apki to Baat hi alg khane sath sath apke bolne me bhi test love you mam',
#  'Delicoious',
#  'thank you auntie ',
#  'Very nice recipe mam',
#  'I have tried it and its taste was very good everyone in my house liked it alott tanks for the recipie ',
#  'Super unti',
#  'Nice recipe nisha g',
#  'nisha ji ur love u',
#  'Thanking for u',
#  'Nice technique mam all ur recipes are coming tasty at first trail',
#  'very nice man bohut acche prathe bante m agar kuch banate hu to aapki hi recipe dekhte hu thanks so much mam',
#  'Ill try mor morning mam ',
#  'Nice yam ',
#  'Wow very nice mom',
#  'Khaiye or mote ho jaye ',
#  'Mam you are blessing for Home Alone Bachelors Thanks lot ',
#  'Misti dokane je poreta hoy tar recipe din',
#  'Nisha mam aap ne coriander powder ko fry Kara hai kyaa',
#  'Hlo mam luv ur method nd ur smile also',
#  'Mam mash ki dal waly parathy ki recipe shar kary ',
#  'kk mam sure will let know how it is made and am sure it will be yum ',
#  'yum recipe will make it tomorrow ',
#  'Thanks lot mam tried to made Nd it was really very tasty thanku so mch',
#  'good cooking ma am',
#  'Awesome awesome awesome awesome awesome awesome',
#  'Helped me ',
#  'thank u',
#  'mam you are the best no one is like you',
#  'Thank you Mam',
#  'Awesome madam',
#  'nice',
#  'Favourite favourite my favourite ',
#  'Thanks',
#  'can we add cheese over potato stuffing ',
#  'Thanks',
#  'I LOVE IT',
#  'Nice mam',
#  'Mam jab main tey karti hun to allo pranda se bahar aa jate hai kya karo',
#  'I love the way she explain she reminds me my mother ',
#  'It very very yummy yummy dish Nisha jiii thanks for uploaded on this video paratha video thanks once again Nisha jiii',
#  'Aunty thanks for sharing such nice receipts m big fan of your recipes When make aloo paratae as you said get the stuffing coming out in the sides when roll them Kindly help me out with this',
#  'i like this process',
#  'Aaj hi banaya Maine aaloo ke parathe so yammi thank you mam love you always ',
#  'Mam aaj mai banaungi kash mai dikhapati',
#  'Wow',
#  'Yummy',
#  'Thank you so much ma am made it today it yummy very easy love you ',
#  'bhookh lg gyi ',
#  'nice',
#  'I made aloo and paneer paratha as per ur recipes and they turned out to be very tasty My daughter loved it Thank you Nishaji ',
#  'Thanks lot you sharing this video',
#  'Aunty ap ghr aa rhi hu mjhe app hath se khana h',
#  'Love the way you explain maam with smily face',
#  'I have tried it it was easy and delicious thanks mam for sharing ',
#  'Aw some Great taste',
#  'Mam maida se paratha bana sakte hai kya',
#  'You are best cook mam love your voice',
#  'Ap bohot achhe se sikhati hn ',
#  'Aunty aap jitni sweet ho utni hi sweet tarike se apne paratha bana na sikhaya hai thank you aunty ',
#  'Wowww ',
#  'wow',
#  'i mam tnx ur kind rply',
#  'so nice',
#  'Wow',
#  'Its yummy but when make my potatoes arent so dry they became soggy wat shud do fr that ',
#  'I like aloo parath',
#  'mam can do it without dried mango powder ',
#  'You can show in picture double sided paranta',
#  'so sweet and nice way of ur cooking madam',
#  'nice recipe ',
#  'Superb',
#  'super parate',
#  'awesome',
#  'Very Yummyyyyyyyyy ',
#  'Cute aunty',
#  'You are talking too much ',
#  'tank you ji maine bana ys achha bana',
#  'nice',
#  'Nisha mam cooked so well thanks for explaining so wonderfully',
#  'Awesome maam ',
#  'Thank you Aunty',
#  'thanks mam it was really helpful',
#  'Nice Mam ',
#  'It is very bad',
#  'wow mem',
#  'nice paratha',
#  'Mujhe stuffing varne me hi problem hota he ',
#  'Yammy ',
#  'mam aapke parathe dekh kr bhuk lg gyi looking so yummy ',
#  'aap bahot sweet ho mam ',
#  'Wow tq for showing how to stuff the parathas ',
#  'Very nice Partha thank you ',
#  'Nice paratha anty thank you so much bohot achhe he ye parathe yaammmiiiiii ',
#  'Thank you madam',
#  'yummy mam hi baut dher bad dkae apke epi ',
#  'Stuffing ko jeers se fry Nahi Kar shaktea hai',
#  'Nisha Mandulia your all video are very excited',
#  'Nisha ji watch all your videos lekin mere se roti aur stuffed paratha gol nahi hote',
#  'Beautiful woman and very good recipe Thank you very much ',
#  'thanq appa ka raspice bhoth follow karthee hum ',
#  'Super Dadi ',
#  'mam r really genius',
#  'very testi',
#  'Mam Main pehle parathe ko bina tel ke sekti hu phir tel lagati hu Ab aapke method se try karungi',
#  'very nice',
#  'Luking very testy ',
#  'I love aloo paratha mam wll try ur process Thankyou ',
#  'Nyc maa ji bahut tasty Hai',
#  'tnx lot mem tody on order aloo paratha tho maine apke video dekhke try karenge thank you so much ',
#  'You are awesome Your recipe are soo good',
#  'niceeee',
#  'very nice',
#  'Thank ji ll try',
#  'You are the best online chef in the whole world Simply amazing love your Hindi too ',
#  'I tried this recipe and it comes out very delicious',
#  'thank nisha mam r recipe is so nice',
#  'What you use to record your videos',
#  'nice',
#  'Bahut acchi hay ap ke resepi bahut acchi tarha samjatei hay',
#  'Porotta and style also very sweet',
#  'Yummy',
#  'This woman is talented Much respect from Pakistan ',
#  'Nice video mam thank so much love ',
#  'Hello Ma am You are fantastic teacher and love your recipes Thank you for patiently explaining every detail of the recipes God Bless You ',
#  'Nisha you are great',
#  'mem aaj hamne aloo ke parante banye te bahut testy bane te thank you mem',
#  'I can get the recipe for the aloo paratha',
#  'Very very nice Pratha',
#  'I like all your recipe and they all are very nice Thank you so much ',
#  'Wow very nice mam',
#  'my fabrit aloo paratha app banate hue dekh mu me pani agaya',
#  'Nice video like it ',
#  'So nice way of teaching Love your style',
#  'Awesome ',
#  'Thanks',
#  'Namastae nisha aunty Thanks lot for helping to make aalo ke paratha and my sister trying this first time',
#  'so yummy ',
#  'yeeee mene bnaye apne hatho se tnx aunty',
#  'It looks very good wish you speak Inglish that we can understand and make copy',
#  'Nice nisha mam',
#  'Hi mam aloo paratha kea sath kon si sabzi serve karoo ',
#  'Hello dear nice it is very easy now Thank you ',
#  'yummy paratha',
#  'Mam its great to see make awesome dishes learn from u',
#  'I will try maam thnxxx',
#  'Thanks lot ma am',
#  'very nice and easy receipe ma am bahot achhe se shikhate ho aap loved it thank you so much ',
#  'Nice liked your recipe its very easy',
#  'super thanks lot mam',
#  ' want to eat that paratha in wild way mannnn ',
#  'sorry mam mujhe ye pasand nahi aaya',
#  'Superb ',
#  'I like your recipes ',
#  'Very nice mossi',
#  'good',
#  'tasty',
#  'thanks mam',
#  'thanks ji',
#  'I like your all recipes mam',
#  'thanks for sharing',
#  'Ma am you are great',
#  'Today my mom is going to make it',
#  'Aunty you talk and look like my mom ',
#  'Thank you',
#  'Thanks aunty and the way you speak really love it You are so sweet ',
#  'Thnx mam Maine Aaj aloo parantha Banaya ND Bhoot yummy bane the pehle Mujhse ye stuffing parantha Bahar Aa Jati thi but Aaj Maine Aapko follow Kiya then result mummy ki help Bina maine parantha banaya thnx once again mam',
#  'Thanks nisha mam',
#  'Thank you anti ji',
#  'mam you are the best ',
#  'thanks mam like this',
#  'what can we use instead of Amchur powder mam ',
#  'Thankyou',
#  'pratha',
#  'nyc',
#  'This was the best way could do aloo parantha did for the first time but yeyyyy it came out so well that my husband liked it lot Thank you so much for the video ',
#  'kk thaqu',
#  'man it really good but jese minutes Me kya ban sakta he',
#  'finally got success thanks lot you made my day ',
#  'marvellous recipe mam thanks but whenever make parathas it always remains undercooked from places what to do please guide',
#  'nice one',
#  'Mam isme jira aur ajvain dal sakte hai ',
#  'Yppppiiiii ',
#  'omg supeer tasty mam',
#  'so yummy ',
#  'nice aunty ji so yummyyy',
#  'aap ki recipe mint ka aap ki aat mint kasa hoa olo banre ho kya',
#  'Very nice',
#  'Mam you are too good trythis recipe and we love it',
#  'Maine aj he banaya hai bht achi boni ha mam thanx',
#  'Love all ur recipies maam ur videos makes it easy for me to cook something',
#  'Very nice don know how to cook this receipe but now can make it easily for my husband and children thanks',
#  'Asalam alikum Aunty love ur all recipes ',
#  'Nishaji aapki recipes bahut acchi rahti hai aajkl to mai kuvh bhi banane se pahile aapki recipe jarur dekhti hu thank you nisha ji',
#  'Nice ',
#  'Nice',
#  'Thanks',
#  'amazing ',
#  'Very nice',
#  'Thanks mam',
#  'Nice',
#  'Superbbbbb ',
#  'I tried ur recipe it came out really good and tasty ',
#  'very Delicious mam',
#  'thanks lot nisha ji',
#  'Thanks',
#  'thanks the way talks is very very loving',
#  'I like your cooking style your best want to tast r food',
#  'super',
#  'Wow yeh to mare mummy bhi banati thi par yeh usa bhi tasty lagta ha',
#  'nice',
#  'Mujhe aapke sikhane ka tarika bahut acha lagta hai',
#  'thanks alot very Nice god bless u',
#  'Ma am love the way you explain us the recipe Exactly the way mom explains ',
#  'Apne maida ya gehu ka atta use Kia hain ',
#  'Aunty JI Aloo paratha AWSOME ',
#  'aloor paratha was famous Indian food',
#  'Superb ',
#  'i made square paratha but it was very tasty ',
#  'Thank you very tasty and interesting presentation',
#  'than you mam lot am going to make right now',
#  'I so happy it has subtitles yey ',
#  'Nice receipy ll surely try',
#  'Hi mam without dried dry mango masala we kat prepare ma',
#  'i like your videos very simple explanation',
#  'Mam mere paranthe sahi se bilte nhi fat jate bataiye me kya kru',
#  'Very nice presentation madam But have used very much oil It will cause risk to health of person',
#  'nice',
#  'Very nice mam',
#  'Itna acha bana hai to Ghar par bhej de',
#  'thanks',
#  'Thank you have made it and my family love it thank you again ',
#  'Nice recipe ',
#  'Very tasty and yummy ',
#  'Hello mam thank soo much For the video',
#  'Tnx Will try this ',
#  'brilliantly explained',
#  'good method g',
#  'Im doing it right away for dinner Thanks for sharing that was really easy and yummy recipe Greetings from Germany ',
#  'really nice',
#  ...]

# %% [markdown]
# ### getting word embedding using XLM transformer model

# %%
from sentence_transformers import SentenceTransformer
#sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('sentence-transformers/stsb-xlm-r-multilingual')

embeddings = model.encode(comments)
print(embeddings)
# Out:
# [[-0.9231262   0.6893022  -0.20165433 ... -0.21720836  0.37221438
#    0.27314365]
#  [ 0.673107    0.74634355  1.8272969  ... -0.2343574  -0.26765293
#    0.1504874 ]
#  [-0.45031944 -0.6066827   1.4488106  ...  0.66524756 -0.4530777
#    0.4871006 ]
#  ...
#  [-0.56239176  0.88402426  0.20911229 ...  0.18294987 -0.26740167
#    0.32738265]
#  [-0.52004     0.63744515  0.08781967 ...  0.00693735  0.07815512
#    0.13753301]
#  [-0.26562455  1.3283886   0.1808225  ... -0.310542    0.5947572
#    0.85663724]]

# %%
xlm_df = pd.DataFrame(embeddings)
xlm_df
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.923126  0.689302 -0.201654 -0.147672  0.572437 -0.238347 -1.096985
# 1     0.673107  0.746344  1.827297 -0.394554  0.501400 -0.177009  0.841197
# 2    -0.450319 -0.606683  1.448811  0.080557  0.605622 -0.183939 -0.314054
# 3     0.422265  0.082410  1.569821 -0.131356  0.304842 -0.636303  0.067043
# 4    -0.232209  0.178038  1.401098  0.312676 -0.357885 -0.222640  0.821089
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.346002  0.865736  0.571761 -0.035625  0.083323 -0.813410  0.508467
# 4896 -0.608627  0.694831  0.374562  0.239316 -0.058654 -0.542161  0.193678
# 4897 -0.562392  0.884024  0.209112  0.042583  0.009933 -0.840245  0.623181
# 4898 -0.520040  0.637445  0.087820  0.145528 -0.328260 -0.590639  0.761291
# 4899 -0.265625  1.328389  0.180823 -0.344769  0.014851 -0.996566  0.650065
#
#            7         8         9    ...       758       759       760  \
# 0     0.206020 -0.156880 -0.280557  ... -0.669488 -0.436450  0.770553
# 1    -0.159353 -0.241521 -0.188106  ... -0.714581  0.027264  0.051650
# 2     0.362417  0.567599 -0.229771  ... -0.589903 -0.508211  0.135435
# 3     1.072215  0.238452 -0.080472  ... -0.283018 -0.300747  0.398938
# 4     0.631840 -0.334245  0.300190  ... -0.928834 -0.808174 -0.187364
# ...        ...       ...       ...  ...       ...       ...       ...
# 4895  0.275815  0.161546 -0.008582  ... -0.273447 -1.000627 -0.310852
# 4896  0.253008  0.555902  0.397440  ... -0.155645 -0.367068 -0.434636
# 4897  0.114400  0.739087  0.355007  ... -0.890240 -0.753912 -0.545932
# 4898 -0.181913  0.283369  0.482278  ... -0.161378 -0.595540 -0.884465
# 4899  0.000128  0.352975  0.148843  ... -0.574965 -1.231012 -0.103236
#
#            761       762       763       764       765       766       767
# 0    -0.925221  0.503625 -0.346710 -0.398681 -0.217208  0.372214  0.273144
# 1     0.061927 -0.854269 -0.642479  0.165548 -0.234357 -0.267653  0.150487
# 2    -1.075377 -0.431511 -0.558016 -0.308165  0.665248 -0.453078  0.487101
# 3    -0.681588 -0.394630 -0.623828 -0.229147 -0.155208 -0.241039 -0.153653
# 4    -1.369940 -0.423332 -0.282127 -0.266035  0.081079 -0.667706  0.659238
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.013242  0.095010 -0.855501 -0.140129  0.272087  0.518576  0.886607
# 4896  0.045370 -0.011500 -0.598854 -0.045648  0.174913 -0.057324  0.250436
# 4897 -0.538228 -0.514585 -0.285386  0.098599  0.182950 -0.267402  0.327383
# 4898 -0.087093 -0.025465 -0.688930 -0.003923  0.006937  0.078155  0.137533
# 4899 -0.187006 -0.157623 -0.531149  0.202219 -0.310542  0.594757  0.856637
#
# [4900 rows x 768 columns]

# %%
xlm_df.to_csv(pwd+"//Datasets//Nisha//SentenceTransformers//xlm_vectorized_Nisha_dataset.csv",index=False)

# %% [markdown]
# ### getting word embedding using BERT transformer model

# %%
from sentence_transformers import SentenceTransformer
#sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('sentence-transformers/bert-base-nli-mean-tokens')
embeddings = model.encode(comments)
print(embeddings)
# Out:
# [[-0.8830953   0.5055446   0.75878036 ...  0.4777759   0.58572876
#    0.61472505]
#  [ 1.0348269   0.97262985  1.5811663  ...  0.26561144  0.1705366
#   -0.30093452]
#  [-0.15356308 -0.6925457   2.0785108  ...  0.7297153  -0.21748221
#    0.31372923]
#  ...
#  [-0.5237374   1.3822352   0.51272595 ...  0.15738086  0.16503288
#    0.77794063]
#  [-0.44348088  1.1082782   0.20232627 ... -0.15942648  0.1830035
#    0.30778834]
#  [-0.14479478  1.709918    0.5949469  ... -0.41594255  0.59035176
#    0.8778952 ]]

# %%
bert_df = pd.DataFrame(embeddings)
bert_df
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.883095  0.505545  0.758780 -0.496859  0.302117  0.063449 -1.549514
# 1     1.034827  0.972630  1.581166  0.176226  0.835957 -0.092160  0.242238
# 2    -0.153563 -0.692546  2.078511  0.449178  0.343400  0.005644 -0.650858
# 3     0.290088 -0.327906  2.176107  0.395264  0.329482 -0.288219 -0.396786
# 4    -0.016789  0.184769  2.339627  0.607132  0.083711 -0.002085  0.314290
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.046594  0.692339  0.936691 -0.186988 -0.016012 -0.558510  0.476935
# 4896 -0.240613  1.008668  0.228633  0.080200  0.084056 -0.507838  0.306651
# 4897 -0.523737  1.382235  0.512726  0.029346 -0.141427 -0.930967  0.084426
# 4898 -0.443481  1.108278  0.202326  0.384840  0.015101 -0.743128  0.355488
# 4899 -0.144795  1.709918  0.594947 -0.266140 -0.318390 -0.287412  0.582295
#
#            7         8         9    ...       758       759       760  \
# 0     0.738195  0.240621 -0.655641  ... -0.681035 -0.991447  0.354245
# 1     0.837126  0.388044  0.005084  ... -0.563849 -0.340941  0.028095
# 2     0.491886  0.558842 -0.282172  ... -0.403861 -0.902996  0.547246
# 3     0.950060  0.330643 -0.041018  ... -0.016144 -0.531465  0.742720
# 4     0.550567 -0.165317 -0.135822  ... -0.645025 -1.484167  0.240233
# ...        ...       ...       ...  ...       ...       ...       ...
# 4895  0.914322  0.366949  0.349095  ... -0.219138 -1.712830 -0.404494
# 4896  0.698342  0.294513  0.309911  ... -0.238726 -0.846050 -0.380347
# 4897  0.530477  0.484652 -0.026270  ... -0.768823 -1.575024 -0.492796
# 4898  0.357614  0.229041  0.357415  ... -0.247549 -1.427949 -1.055043
# 4899  0.391632  0.171080  0.021257  ... -0.543095 -1.279411 -0.372910
#
#            761       762       763       764       765       766       767
# 0    -1.323432  0.367442 -1.050682 -0.391647  0.477776  0.585729  0.614725
# 1    -0.093787 -0.904434 -0.972987  0.066746  0.265611  0.170537 -0.300935
# 2    -1.331074 -0.538702 -0.586896 -0.333883  0.729715 -0.217482  0.313729
# 3    -0.693241 -0.495408 -0.445131 -0.031817 -0.046214 -0.149602  0.111355
# 4    -1.579761 -0.176480 -0.702776 -0.354539  0.068534 -0.558782  0.368174
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.560959  0.405403 -1.224527 -0.143131  0.470783  0.725982  0.930996
# 4896  0.159829  0.011457 -0.561292 -0.325374 -0.222089  0.024769  0.419447
# 4897 -0.942826 -0.184203 -0.767271 -0.192130  0.157381  0.165033  0.777941
# 4898 -0.362667  0.233421 -0.881299  0.041089 -0.159426  0.183004  0.307788
# 4899 -0.955213 -0.141825 -0.630313  0.202183 -0.415943  0.590352  0.877895
#
# [4900 rows x 768 columns]

# %%
bert_df.to_csv(pwd+"//Datasets//Nisha//SentenceTransformers//bert_vectorized_Nisha_dataset.csv",index=False)

# %% [markdown]
# ### getting word embedding using GPT transformer model

# %%
from sentence_transformers import SentenceTransformer
#sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('Muennighoff/SGPT-125M-mean-nli')

embeddings = model.encode(comments)
print(embeddings)
# Out:
# [[ 1.1217804   0.69908744  0.20934486 ...  0.07513619  1.1218945
#    1.7190275 ]
#  [ 0.9883055   2.1585433  -0.31595352 ... -0.42519552  0.58054024
#    0.5243883 ]
#  [-0.4865899   1.1414863  -0.31594455 ... -0.56561166  0.06194921
#    0.52448285]
#  ...
#  [ 0.11909113  0.3872833   0.06580309 ...  0.215436   -0.63942003
#    0.9244627 ]
#  [-0.4514768   1.3336447  -0.20508    ...  0.63162816 -0.45635936
#    0.03426715]
#  [ 0.69585705  0.9427703  -0.01147925 ... -0.26781577  0.3572883
#    0.42756945]]

# %%
gpt_df = pd.DataFrame(embeddings)
gpt_df
# Out:
#            0         1         2         3         4         5         6    \
# 0     1.121780  0.699087  0.209345  0.242259 -0.152073  0.215735 -0.911569
# 1     0.988306  2.158543 -0.315954 -1.460089  1.528875  1.821503 -0.959935
# 2    -0.486590  1.141486 -0.315945 -0.003996  1.170209 -0.055596 -0.224662
# 3    -0.020259 -0.414121  0.158213 -0.540366  2.101993 -0.104313 -0.289246
# 4     0.492701  0.171463  0.158686  0.136624  1.130372  1.253407 -0.170601
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.435918 -0.007518 -0.568296 -0.839353  0.860203  1.395772 -0.563079
# 4896 -0.041844  0.750290 -0.790915 -0.650757 -0.165346  2.392101 -0.503653
# 4897  0.119091  0.387283  0.065803 -1.032873  0.925600  2.303024 -0.232414
# 4898 -0.451477  1.333645 -0.205080 -0.460406  0.772698  0.901386 -0.431625
# 4899  0.695857  0.942770 -0.011479 -0.731417  0.612665  1.746587 -0.476065
#
#            7         8         9    ...       758       759       760  \
# 0     1.962587  0.791186 -0.117048  ...  0.887560  0.225670  0.318917
# 1    -0.916340  0.359719  0.923443  ... -0.134906  0.374383  2.004292
# 2    -0.798140  1.267687 -0.270818  ... -0.041519  0.157196 -0.523254
# 3    -0.752499  0.217500  0.474152  ...  0.129466 -0.647680  0.418745
# 4    -0.036485  0.389755  0.149789  ...  0.107071  0.098522  0.757091
# ...        ...       ...       ...  ...       ...       ...       ...
# 4895  0.503159 -0.272290  0.605145  ... -0.442174 -0.023483  0.208158
# 4896  0.829643  0.080246 -0.166595  ... -0.578195  0.245159  0.358389
# 4897  0.940163 -0.457403  0.124279  ... -0.361983 -0.180416  1.160810
# 4898  0.179475 -0.061893  0.253041  ... -0.751042 -1.033683 -0.321387
# 4899  1.091499 -1.035746 -0.198871  ...  0.014826  0.499903  0.108556
#
#            761       762       763       764       765       766       767
# 0    -1.024972  0.082028  0.161954 -0.001839  0.075136  1.121894  1.719028
# 1    -0.440727 -0.479519 -1.605058 -0.321332 -0.425196  0.580540  0.524388
# 2    -0.065974  0.866608 -1.341049 -0.330101 -0.565612  0.061949  0.524483
# 3    -0.132340 -0.189253 -1.361162 -0.815769  0.215549 -0.580044  0.624534
# 4     0.140605 -0.339048 -1.621049 -0.390446  0.290734 -0.969914  0.887317
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.572756 -0.099453 -0.342356 -0.686135  0.168298 -0.423028  1.405525
# 4896 -0.651669  0.512639 -0.206927 -0.400877  0.072504 -0.188466  0.913997
# 4897 -0.471919 -0.981674 -1.000404 -0.016711  0.215436 -0.639420  0.924463
# 4898 -1.076963  1.057944  0.015422 -0.279496  0.631628 -0.456359  0.034267
# 4899 -0.793424  0.136751 -0.060420  0.461840 -0.267816  0.357288  0.427569
#
# [4900 rows x 768 columns]

# %%
gpt_df.to_csv(pwd+"//Datasets//Nisha//SentenceTransformers//gpt_vectorized_Nisha_dataset.csv",index=False)

# %% [markdown]
# ### getting word embedding using ganesh bert hinglish

# %%
from sentence_transformers import SentenceTransformer
#sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('ganeshkharad/gk-hinglish-sentiment')

embeddings = model.encode(comments)
print(embeddings)
# Out:
# WARNING:root:No sentence-transformers model found with name C:\Users\murth/.cache\torch\sentence_transformers\ganeshkharad_gk-hinglish-sentiment. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at C:\Users\murth/.cache\torch\sentence_transformers\ganeshkharad_gk-hinglish-sentiment were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [[-0.14860971 -0.06620098  0.19706543 ...  1.1634536  -0.4461153
#    0.24545802]
#  [-0.5970791  -0.29259342 -0.0531439  ... -0.59293765  0.726723
#    0.06853815]
#  [-0.0684687  -0.05767049  0.20692334 ...  1.1055846  -0.44409359
#    0.38638443]
#  ...
#  [-0.09857559  0.09547041  0.24071969 ... -0.3901195  -0.10563625
#   -0.66120684]
#  [-0.03190724  0.16914447  0.19587335 ... -0.30780855 -0.07015739
#   -0.68790066]
#  [-0.05192059  0.00714015  0.16950852 ... -0.05834529  0.02964392
#   -0.6432214 ]]

# %%
gkb_df = pd.DataFrame(embeddings)
gkb_df
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.148610 -0.066201  0.197065 -0.403903 -0.806435  0.163926 -0.676606
# 1    -0.597079 -0.292593 -0.053144  0.955878  0.154275  1.488085  1.211662
# 2    -0.068469 -0.057670  0.206923 -0.257298 -0.897219  0.185309 -0.579785
# 3    -0.093445 -0.033763  0.161939 -0.328855 -0.860179  0.216090 -0.598368
# 4    -0.163966  0.028172  0.190103 -0.512290 -0.784636  0.185264 -0.709566
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895  0.226045 -0.094742  0.119419  0.381047 -0.290211  0.211011  0.524123
# 4896 -0.048951  0.110394  0.228828 -0.935137  0.529755 -0.827624 -0.806533
# 4897 -0.098576  0.095470  0.240720 -0.959416  0.535217 -0.770665 -0.826162
# 4898 -0.031907  0.169144  0.195873 -0.892863  0.520891 -0.887377 -0.840673
# 4899 -0.051921  0.007140  0.169509 -0.868716  0.166615 -1.034012 -0.700921
#
#            7         8         9    ...       758       759       760  \
# 0     0.013971  0.098064  0.408271  ... -0.288038  0.072760 -0.653422
# 1     0.066730 -0.948317  1.553937  ... -0.046048 -0.499181  0.321593
# 2    -0.161358 -0.107629  0.636659  ... -0.366615 -0.103005 -0.670450
# 3    -0.052339 -0.051332  0.572519  ... -0.335801 -0.055050 -0.662456
# 4     0.230495  0.274939  0.327548  ... -0.333750  0.148627 -0.595801
# ...        ...       ...       ...  ...       ...       ...       ...
# 4895 -0.062333  0.089157 -0.015754  ...  0.788538 -0.023463 -0.143083
# 4896  0.209439  0.209455 -1.550826  ...  0.841959  0.833740 -0.287667
# 4897  0.252479  0.248617 -1.536408  ...  0.885185  0.839682 -0.301128
# 4898  0.143190  0.270169 -1.510137  ...  0.832667  0.825980 -0.344026
# 4899  0.297469  0.310407 -1.594517  ...  0.910474  0.835642 -0.724401
#
#            761       762       763       764       765       766       767
# 0    -0.440201 -1.417569 -1.166178 -0.615401  1.163454 -0.446115  0.245458
# 1     0.096602 -0.569029  0.227171  1.264960 -0.592938  0.726723  0.068538
# 2    -0.254204 -1.605515 -1.287513 -0.651495  1.105585 -0.444094  0.386384
# 3    -0.338558 -1.544574 -1.221142 -0.631080  1.120134 -0.425561  0.345815
# 4    -0.490122 -1.120456 -0.912502 -0.643764  1.007517 -0.451392  0.073760
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.607732  0.562898  0.902074  0.178966 -0.119736  1.018532 -0.829621
# 4896 -0.320312  1.497882  0.158816 -0.453379 -0.348677 -0.083214 -0.696761
# 4897 -0.346285  1.475176  0.106338 -0.457539 -0.390119 -0.105636 -0.661207
# 4898 -0.283056  1.537292  0.261050 -0.516793 -0.307809 -0.070157 -0.687901
# 4899 -0.474995  1.383953  0.456463 -0.744886 -0.058345  0.029644 -0.643221
#
# [4900 rows x 768 columns]

# %%
gkb_df.to_csv(pwd+"//Datasets//Nisha//SentenceTransformers//bert_vectorized_Nisha_dataset_gkb.csv",index=False)

# %% [markdown]
# ### getting word embedding using Narasimha distilbert

# %%
from sentence_transformers import SentenceTransformer
#sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('Narasimha/hinglish-distilbert')

embeddings = model.encode(comments)
print(embeddings)
# Out:
# WARNING:root:No sentence-transformers model found with name C:\Users\murth/.cache\torch\sentence_transformers\Narasimha_hinglish-distilbert. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at C:\Users\murth/.cache\torch\sentence_transformers\Narasimha_hinglish-distilbert were not used when initializing DistilBertModel: ['pre_classifier.bias', 'pre_classifier.weight', 'classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [[-0.08390602 -0.06880353 -0.30821222 ...  0.36598063  0.26032338
#    0.02925958]
#  [ 0.08827831  0.55499923 -0.44701475 ...  1.1024431  -0.3801523
#   -0.43658903]
#  [-0.12722974  0.02991491  0.05581726 ... -0.30840018  0.40898553
#    0.16943222]
#  ...
#  [-0.07084482 -0.03373488  0.09586931 ...  0.11868706 -0.22538331
#   -0.12845972]
#  [-0.171654    0.25636497 -0.4297402  ...  0.02309143 -0.29467773
#   -0.27863392]
#  [ 0.04145664  0.72432345 -0.16390142 ...  0.15531583 -0.27489024
#   -0.195358  ]]

# %%
ndisbert_df = pd.DataFrame(embeddings)
ndisbert_df
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.083906 -0.068804 -0.308212  0.301010  0.084590  0.548366  0.285091
# 1     0.088278  0.554999 -0.447015  0.937224 -0.210401 -0.439736  0.311016
# 2    -0.127230  0.029915  0.055817  0.675761  0.114652  0.308946  0.339394
# 3    -0.327787  0.296509  0.104139  0.674247  0.205344  0.310077  0.069242
# 4    -0.048290 -0.088255 -0.228519  0.418398  0.310531  0.387664  0.201134
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895  0.061975  0.293905 -0.302392  0.688694  0.449891 -0.206167 -1.172134
# 4896 -0.167636  0.013926 -0.327148  0.396188  0.279400 -0.263899 -1.006600
# 4897 -0.070845 -0.033735  0.095869  0.354693  0.260827  0.203064 -0.880967
# 4898 -0.171654  0.256365 -0.429740  0.317579  0.136637 -0.207173 -1.016747
# 4899  0.041457  0.724323 -0.163901  0.987131  0.527002  0.013458 -0.935222
#
#            7         8         9    ...       758       759       760  \
# 0     0.093824 -0.194021 -0.185985  ... -0.450472  0.630399 -1.245703
# 1     0.268696  0.236798 -0.567009  ...  0.481537 -0.438239 -0.005366
# 2    -0.040615 -0.407329 -0.377539  ... -0.243705  0.279745 -1.083806
# 3    -0.268018 -0.472436 -0.208399  ... -0.300963  0.778473 -0.759574
# 4     0.339776 -0.371588 -0.370217  ... -0.690023  0.274251 -0.794400
# ...        ...       ...       ...  ...       ...       ...       ...
# 4895  0.302992  0.093260 -0.081369  ...  0.080650  0.159515 -0.518239
# 4896 -0.026752 -0.025809  0.182364  ...  0.009754  0.165784 -0.285873
# 4897  0.438215 -0.227559  0.055963  ...  0.175565  0.034195 -0.459597
# 4898  0.236213  0.005945 -0.178087  ...  0.504874  0.285852 -0.183360
# 4899  0.305093  0.132562 -0.212674  ...  0.373531 -0.144319 -0.511096
#
#            761       762       763       764       765       766       767
# 0    -0.290122  0.489035 -0.734231 -0.102933  0.365981  0.260323  0.029260
# 1    -0.944921 -1.010036 -0.205987 -0.173048  1.102443 -0.380152 -0.436589
# 2    -0.147592  0.582820 -0.736774 -0.012404 -0.308400  0.408986  0.169432
# 3    -0.369135  0.386196 -0.831839 -0.468969 -0.074690  0.504364  0.128752
# 4    -0.337823  0.246688 -0.919458  0.134224 -0.073016  0.098417  0.294232
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.191403 -0.145999  0.636879 -0.517051  0.370742 -0.210431 -0.173467
# 4896  0.140358  0.300185  0.745232 -0.188191  0.273062 -0.058382 -0.168797
# 4897  0.084805  0.070126  0.007569  0.162150  0.118687 -0.225383 -0.128460
# 4898 -0.042295 -0.257925  0.918677 -0.293232  0.023091 -0.294678 -0.278634
# 4899 -0.167500 -0.163308  0.626009 -0.258769  0.155316 -0.274890 -0.195358
#
# [4900 rows x 768 columns]

# %%
ndisbert_df.to_csv(pwd+"//Datasets//Nisha//SentenceTransformers//bert_vectorized_Nisha_dataset_ndisbert.csv",index=False)

# %% [markdown]
# ### getting word embedding using verloop bert hinglish

# %%
from sentence_transformers import SentenceTransformer
#sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('verloop/Hinglish-Bert')

embeddings = model.encode(comments)
print(embeddings)
# Out:
# WARNING:root:No sentence-transformers model found with name C:\Users\murth/.cache\torch\sentence_transformers\verloop_Hinglish-Bert. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at C:\Users\murth/.cache\torch\sentence_transformers\verloop_Hinglish-Bert were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [[ 0.05825204 -0.04497383  0.3169314  ...  0.00594678 -0.12946576
#   -0.19330145]
#  [ 0.15444897 -0.92527664  1.0948087  ... -0.42405504  0.6786481
#   -1.0724133 ]
#  [ 0.21343458 -0.05968074  0.26639783 ... -0.11337209  0.0374006
#   -0.1638125 ]
#  ...
#  [-0.09550128 -0.2482521   0.14104392 ...  0.02395414 -0.19587298
#   -0.3109267 ]
#  [-0.23648068 -0.28269923  0.2187663  ...  0.12523854 -0.10806563
#   -0.28703853]
#  [-0.2628848  -0.03599002  0.10348365 ...  0.13775069 -0.20876127
#   -0.26815286]]

# %%
vbert_df = pd.DataFrame(embeddings)
vbert_df
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.058252 -0.044974  0.316931 -0.030543  0.311786 -0.010969 -0.010019
# 1     0.154449 -0.925277  1.094809  0.568340  0.186218  1.047410  0.071202
# 2     0.213435 -0.059681  0.266398  0.182792  0.128358  0.108804  0.156871
# 3     0.100751 -0.096210  0.503563  0.183250  0.409448  0.145036 -0.034270
# 4     0.119568 -0.241228  0.263781  0.232283  0.405295  0.453661  0.038153
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.338858 -0.165245  0.411556  0.129420  0.226469  0.538784 -0.227770
# 4896 -0.286660 -0.155313  0.209322 -0.014334  0.372028  0.056599 -0.079684
# 4897 -0.095501 -0.248252  0.141044  0.108960  0.258361  0.464471 -0.117141
# 4898 -0.236481 -0.282699  0.218766  0.036269  0.275384  0.160253 -0.017913
# 4899 -0.262885 -0.035990  0.103484  0.094577  0.227268  0.329541 -0.180149
#
#            7         8         9    ...       758       759       760  \
# 0     0.119059  0.249972 -0.051852  ...  0.101570  0.298153 -0.637974
# 1    -0.073735  0.622464  0.855457  ... -0.582476  0.280009 -0.625024
# 2     0.225032  0.137205 -0.156471  ...  0.056478  0.073451 -0.558696
# 3     0.509119  0.301562 -0.136219  ...  0.025368 -0.011376 -0.894290
# 4    -0.220380  0.112737 -0.164271  ... -0.006300  0.115420 -0.671467
# ...        ...       ...       ...  ...       ...       ...       ...
# 4895 -0.097606 -0.027321 -0.311945  ...  0.092522  0.512336 -0.600762
# 4896  0.012778  0.142378 -0.098753  ...  0.013229  0.523600 -0.696458
# 4897  0.113425  0.022648 -0.265082  ... -0.261413  0.427431 -0.584224
# 4898  0.160959 -0.002355 -0.239232  ... -0.084267  0.466852 -0.667058
# 4899  0.058105 -0.196463 -0.117745  ... -0.006526  0.368922 -0.396648
#
#            761       762       763       764       765       766       767
# 0    -0.087362 -0.133055 -0.261190 -0.037889  0.005947 -0.129466 -0.193301
# 1     0.065137  0.826457 -0.330216  0.577794 -0.424055  0.678648 -1.072413
# 2     0.339373 -0.034474  0.256482  0.151185 -0.113372  0.037401 -0.163813
# 3     0.247521 -0.224709 -0.031659  0.141739 -0.048020  0.065140 -0.188098
# 4    -0.233030 -0.628569 -0.365300 -0.187611 -0.125059 -0.411926 -0.568473
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895 -0.410102  0.249226 -0.087972  0.021356 -0.191754 -0.211953 -0.316678
# 4896 -0.432414  0.186748 -0.110548  0.093707 -0.012317 -0.230212 -0.304713
# 4897 -0.494822 -0.135214 -0.217614 -0.031491  0.023954 -0.195873 -0.310927
# 4898 -0.587945 -0.107710 -0.214318 -0.037308  0.125239 -0.108066 -0.287039
# 4899 -0.516614  0.191241 -0.357000 -0.026606  0.137751 -0.208761 -0.268153
#
# [4900 rows x 768 columns]

# %%
vbert_df.to_csv(pwd+"//Datasets//Nisha//SentenceTransformers//bert_vectorized_Nisha_dataset_vbert.csv",index=False)

# %%
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\murth\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ### normal vectorization Bert

# %%
from transformers import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained("bert-base-uncased")
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
print(output)

# %%
for x in output[1]:
    print(len(x))

# %% [markdown]
# ### normal vectorization GPT2

# %%
from transformers import GPT2Tokenizer, GPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2')
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
print(output)

# %%
print(output[1])
