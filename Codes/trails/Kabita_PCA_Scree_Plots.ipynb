# %%
# importing Libraries
try:
    import os, sys
    import pandas as pd
    import numpy as np
    from sklearn.preprocessing import StandardScaler
    from sklearn.decomposition import PCA
    import matplotlib.pyplot as plt
    import seaborn as sns
except Exception as e:
    print("Error because of",e)
pwd = os.getcwd()

# %%
def scree_graph(df, data_set):
    scaler_model=StandardScaler()
    scaled_data= scaler_model.fit_transform(df)
    #print(scaled_data)
    # Doing  PCA giving number of Components(dimensions)
    pca_comp=PCA(n_components=20)
    x_pca_comp=pca_comp.fit_transform(scaled_data)
    variances_list = pca_comp.explained_variance_ratio_
    plt.plot(list(range(1,21)), variances_list, 'o-', color='black')
    plt.title('Scree Plot of '+data_set+" data")
    plt.xticks(range(21))
    plt.xlabel('Principal Component')
    plt.ylabel('Variance Explained')
    plt.show()

# %% [markdown]
# ### Bag Of Words Scree Plots

# %%
# TFIDF vectorized data
df = pd.read_csv(pwd+"//Datasets//Kabita//BagOfWords//tfidf_500_vectors.csv")
scree_graph(df, 'TFIDF')

# %%
# Count Vectorizer data
df = pd.read_csv(pwd+"//Datasets//Kabita//BagOfWords//cv_500_vectors.csv")
scree_graph(df, 'Count Vectorized data')

# %%
# Term Frequency Vectorizer data
df = pd.read_csv(pwd+"//Datasets//Kabita//BagOfWords//tf_500_vectors.csv")
scree_graph(df, 'term Frequency Vectorized data')

# %% [markdown]
# ### Sentence Transformers Scree Plots

# %%
# Bert Vectorized data by Sentence Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//bert_vectorized_kabita_dataset.csv")
scree_graph(df, 'Bert Vectorized data by Sentence Transformers')

# %%
# gkb Bert Vectorized data by Sentence Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//bert_vectorized_kabita_dataset_gkb.csv")
scree_graph(df, 'GKB Bert Vectorized data by Sentence Transformers')

# %%
# Narsimha distilBert Vectorized data by Sentence Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//bert_vectorized_kabita_dataset_ndisbert.csv")
scree_graph(df, 'N DistilBert Vectorized data by Sentence Transformers')

# %%
# verloop Bert Vectorized data by Sentence Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//bert_vectorized_kabita_dataset_vbert.csv")
scree_graph(df, 'V Bert Vectorized data by Sentence Transformers')

# %%
# GPT Vectorized data by Sentence Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//gpt_vectorized_kabita_dataset.csv")
scree_graph(df, 'GPT Vectorized data by Sentence Transformers')

# %%
# XLM Vectorized data by Sentence Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//SentenceTransformers//xlm_vectorized_kabita_dataset.csv")
scree_graph(df, 'XLM Vectorized data by Sentence Transformers')

# %% [markdown]
# ### Fine Tuned Transformers Scree Plots

# %%
# Bert Vectorized data by Fine Tuned Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//bert_base_finetuned_vectorized_kabita_dataset.csv")
scree_graph(df, 'Bert Vectorized data by Fine Tuned Transformers')

# %%
# Hinglish Bert Vectorized data by Fine Tuned Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//vbert_hinglish_finetuned_vectorized_kabita_dataset.csv")
scree_graph(df, 'Hinglish Bert Vectorized data by Fine Tuned Transformers')

# %%
# GPT Vectorized data by Fine Tuned Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//gpt_base_finetuned_vectorized_kabita_dataset.csv")
scree_graph(df, 'GPT Vectorized data by Fine Tuned Transformers')

# %%
# Hinglish GPT Vectorized data by Fine Tuned Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//gpt_hinglish_finetuned_vectorized_kabita_dataset.csv")
scree_graph(df, 'Hinglish GPT Vectorized data by Fine Tuned Transformers')

# %%
# XLM Vectorized data by Fine Tuned Transformers data
df = pd.read_csv(pwd+"//Datasets//Kabita//FineTunedTransformers//xlm_base_finetuned_vectorized_kabita_dataset.csv")
scree_graph(df, 'XLM Vectorized data by Fine Tuned Transformers')
