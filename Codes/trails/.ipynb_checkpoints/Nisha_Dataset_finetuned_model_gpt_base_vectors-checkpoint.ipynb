# %%
import pandas as pd
import numpy as np
import os,sys
import re
pwd = os.getcwd()

# %%
# reading dataset
kb_df = pd.read_csv(pwd+"//Datasets//Nisha//Input//Nishafin.csv", encoding_errors='ignore')
kb_df
# Out:
#                               id  \
# 0     Ugz7LQV0ZWpuNnjBaxJ4AaABAg
# 1     UgxvWJ_kJL2nePTkg2N4AaABAg
# 2     UgxxeUmiH9f8XOZZWr14AaABAg
# 3     Ugz-UPvwHMx4nSKVoCB4AaABAg
# 4     UgzfXhbesBABQzi4-m94AaABAg
# ...                          ...
# 4895  UgyGSYkiLHY3dWl4AZt4AaABAg
# 4896  Ugzx3OSiIndEsUN54IB4AaABAg
# 4897  UgxRwq2MsR9csHLc7MJ4AaABAg
# 4898  UgxxO1vtL-g7PPRVXBp4AaABAg
# 4899  UgyNWcXDvbZF1I7S8rh4AaABAg
#
#                                             commentText  Labels
# 0                              i  love potato ke prathe       2
# 1     Wwaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaww       3
# 2                                                  Nice       3
# 3                                           Wow Amazing       3
# 4                                       Thank you madam       1
# ...                                                 ...     ...
# 4895  Mam kya hum butter Ki bjaye desi ghee bhi daal...       7
# 4896  Ky hum condensed milk k jagha par amul powder ...       7
# 4897  Very yummy cake mam...condensed milk k jagah a...       5
# 4898  mad aapne powder sugar or condensed milk dono ...       7
# 4899  cake microwave oven se nikalne k baad thodi de...       7
#
# [4900 rows x 3 columns]

# %%
kb_df.shape
# Out:
# (4900, 3)

# %%
# replacing enter with ';'
kb_df['commentText'] = kb_df['commentText'].str.replace('\n',';')
kb_df
# Out:
#                               id  \
# 0     Ugz7LQV0ZWpuNnjBaxJ4AaABAg
# 1     UgxvWJ_kJL2nePTkg2N4AaABAg
# 2     UgxxeUmiH9f8XOZZWr14AaABAg
# 3     Ugz-UPvwHMx4nSKVoCB4AaABAg
# 4     UgzfXhbesBABQzi4-m94AaABAg
# ...                          ...
# 4895  UgyGSYkiLHY3dWl4AZt4AaABAg
# 4896  Ugzx3OSiIndEsUN54IB4AaABAg
# 4897  UgxRwq2MsR9csHLc7MJ4AaABAg
# 4898  UgxxO1vtL-g7PPRVXBp4AaABAg
# 4899  UgyNWcXDvbZF1I7S8rh4AaABAg
#
#                                             commentText  Labels
# 0                              i  love potato ke prathe       2
# 1     Wwaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaww       3
# 2                                                  Nice       3
# 3                                           Wow Amazing       3
# 4                                       Thank you madam       1
# ...                                                 ...     ...
# 4895  Mam kya hum butter Ki bjaye desi ghee bhi daal...       7
# 4896  Ky hum condensed milk k jagha par amul powder ...       7
# 4897  Very yummy cake mam...condensed milk k jagah a...       5
# 4898  mad aapne powder sugar or condensed milk dono ...       7
# 4899  cake microwave oven se nikalne k baad thodi de...       7
#
# [4900 rows x 3 columns]

# %%
# removing emojis
import emoji

def remove_emoji(text):
    return emoji.get_emoji_regexp().sub(u'', text)

# %%
# remove special characters 
import re

def remove_spechar(text):
    r = re.sub(r'\W+', ' ', text)
    return r.strip()

# %%
X = list(map(remove_emoji,list(kb_df['commentText'])))
X = list(map(remove_spechar,X))
y=list(kb_df['Labels'])
# Out:
# C:\Users\murth\AppData\Local\Temp/ipykernel_19048/1096523203.py:5: DeprecationWarning: 'emoji.get_emoji_regexp()' is deprecated and will be removed in version 2.0.0. If you want to remove emoji from a string, consider the method emoji.replace_emoji(str, replace='').
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'
#   return emoji.get_emoji_regexp().sub(u'', text)

# %%
import torch
from transformers import GPT2Tokenizer, GPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
print(X)
# Out:
# ['i love potato ke prathe', 'Wwaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaww', 'Nice', 'Wow Amazing', 'Thank you madam', 'nice', 'Nice', 'Execllent women', 'soo kind', 'I canâ t believe she has 6 6 million subs from 2019', 'Nice', 'thanksðŸ Š', 'Atta flour means wheat flour', 'Paratha Liked the kitchen design', 'Tasty aloo paratha', 'Thanks Aunty â ï', 'Superb', 'Aunty aapne bahut hi acha aur bqhut simplicity ke saath explain kiya Aise hamare Desh me teachers ho jaye to phir kisi bacche ko tutions ki need ni ho U are such a inspiration And paratha is also very good healthy', 'Your instructions are really useful ma am', 'ur way of explaining is best aunty ji', 'I love this word thody se chotty thody se bady bana sakty hyn', 'nisha aunty you are soooooooo humble and sweet keep it upðŸ ðŸ ðŸ ðŸ ðŸ ðŸ ðŸ ðŸ ðŸ ðŸ ðŸ ðŸ žðŸ ðŸ ðŸ ŸðŸ', 'Wao', 'thanks', 'Awesome', 'app mera bhahi hote toh bariya hota roj kuch na kuch naya khane ko milta', 'Nice', 'Hello Nisha anti mai new hun bht mazy k pharahty bane muje se ap ki video dhek kr thank God muje reply kijy ga nd Maine kuch or bana hu Kia likhun', 'Beshk u r great Blessings frm pakistan ðŸ', 'Madam aap thoda nail cut karo suggestion hai mera cooking karte time warna gloves wear karo', 'wowðŸ', 'Love from Kerala', 'bhot Asha aalo vala prantha', 'Vedio bohot accha laga mam', 'Nice recipe easy to cook ðŸ ŒðŸ Œ', 'Yummy yummy super yummy ðŸ ðŸ ðŸ aaloo prathe ðŸ', 'mam mere potatoes ko mne boil krke cooker mein chod diye the 1hour after mne potatoes ko cheel ke masala banaya to masala kafi loose ho gya uske baad mne unhe choka bhi laga diya phir bhi parathe nhi bn rhe h pls bataye kya kre', 'yummy', 'she is still young due to her cooking', 'Very nice madam ji', 'Mam u are highly talented and ur cooking skills are extraordinaryðŸ ðŸ ðŸ ŒðŸ Œ', 'Good aunty', 'Your voice is nice', 'nice', 'You explain very clearly and sweetly ma am Thank you', 'Mam jab paratha belte hai tao sara masala corner pe aa jata h center me kuch nhi rahta', 'Also paratha receipe nice very niceðŸ ŒðŸ ŒðŸ ŒðŸ ŒðŸ ŒðŸ Œ', 'Nisha mam i tried it n it was too good i make parathas dis way for my kids once in a week n dey enjoy it u showed a very awesome recipe God bless u n ur loved ones', 'Thanks mam It s very easy and yummy', 'Wow wow wow mouth watering', 'My mom is not here so I wanted to make aloo ka paratha and this vid helped me thanks', 'Madam oil ka place ghee use kar sakthe he kya', 'Very delicious ðŸ ŒðŸ Œ', 'very good and nice recipe mam', 'Thanks aap itna Achha paratha Banai hai aur aap bahut acchi hai thanks', 'Itna oilðŸ', 'Osm pratha aunty ji', 'Who try this please one like', 'Wow apke parathe kitte kitte mast h wow mughe to abi khane ka mn kr rhe h mae bi aj hi bnaungi', 'Thank you ðŸ', 'Ma am really your all recipes are testy i m ur big fan this paratha recipe also very nice', 'Majedar bana hai Aloo paratha ðŸ ŒðŸ Œ', 'M newly mrd i dono anythng to cook my hubby lyks alu paratha tqsm mam fr dis recipeðŸ ðŸ', 'Nyc', 'This women is very good', 'Very good pratha ji', 'Thanku mam', 'Very very nice holiday i cook my grandson im also cooking expert in all once again i wish you', 'Thank you mam bht testy hai', 'Nice bhabi ji', 'Mam AAP bahut ache tarike se sikhati h thanks', 'Thanku so much', 'I am trying early morning', 'Nice Aunty ji', 'Thank you I tried it It is very tasty', 'Thanks mummy ji', 'auntie its me again THE JOKERfrom kashmir and i wanted to ask that can we use gram flour besan instead of wheat flour maida', 'Very nice parathe', 'Super mam', 'koi new recipe dijiye Nisha ji', 'Thanks', 'Yummmmmmy ma abi try krny lgii hu', 'Nice recipe aap ka andaz itna pyara he samjhane ka ke kia hi baat he thanks for the recipe', 'Very yammyyyyyyyyyyyyyyyy', 'Really nice Paratha ðŸ ðŸ', 'I will try', 'MarshAllah beautiful excellent parathay', 'Mam m koi bhi stuffed paratha bnati hu to sari stuffing kinaro p aa jati h or beech m sirf aata reh jata h To kya kru ki stuffing pure parathe m evenly lg jaye', 'aaj to me bhi  ...

# %%
# Load pre-trained model (weights)
model = GPT2Model.from_pretrained('gpt2',
                                  output_hidden_states = True # Whether the model returns all hidden-states.
                                  )


# Put the model in "evaluation" mode, meaning feed-forward operation.
model.eval()
                                  
def gpt_vectorization(text):
    # Split the sentence into tokens.    
    inputs = tokenizer(text, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
        hidden_states = outputs[2]
    token_vecs = hidden_states[-1][0]
    
    # Calculate the average of all the token vectors.
    sentence_embedding = torch.mean(token_vecs, dim=0)
    
    return np.array(sentence_embedding)

# %%
gpt_vectors = list(map(gpt_vectorization,X))

# %%
print(gpt_vectors)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
gpt_df = pd.DataFrame(gpt_vectors)
gpt_df
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.230530 -0.339290 -0.264316 -0.027485 -0.137263 -0.153484  0.300358
# 1    -0.469014 -0.150256 -0.767726 -0.431441  0.046556  0.300239  1.874201
# 2     0.017205 -0.084341 -0.345837 -0.115122 -0.048592 -0.224948  0.192404
# 3     0.077129 -0.248630 -0.239150 -0.208758  0.015332  0.016530  3.026008
# 4     0.440127 -0.112635 -0.822034 -0.222506 -0.106658 -0.527603  2.898507
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895  0.011264 -0.315829 -0.417804 -0.173791 -0.162499  0.098799 -0.074307
# 4896  0.011538 -0.533816 -0.795222 -0.103838  0.028672  0.324614 -0.770983
# 4897 -0.053999 -0.323132 -0.740617 -0.094730 -0.050868  0.247032 -0.701885
# 4898  0.173631 -0.454831 -1.039667 -0.462610 -0.131240  0.280289 -0.098983
# 4899 -0.058822 -0.050684 -0.537083 -0.163502 -0.234180  0.061455 -0.974473
#
#            7         8         9    ...       758       759       760  \
# 0    -0.042312  0.028767  0.031518  ... -0.119128  0.199092  0.232858
# 1     0.425039  0.205365 -0.095057  ...  0.192414  0.561491  0.000935
# 2    -0.077087 -0.040943  0.002648  ... -0.120221  0.176281 -0.182494
# 3     0.091812 -0.323113 -0.058415  ...  0.030826 -0.044415 -0.022564
# 4     0.163939 -0.193126 -0.258616  ... -0.058268  0.472159  0.525021
# ...        ...       ...       ...  ...       ...       ...       ...
# 4895  0.052986  0.166126  0.355774  ... -0.036312  0.306247  0.146232
# 4896  0.008326 -0.270028 -0.072741  ...  0.004980  0.158303  0.070521
# 4897  0.287595 -0.159306 -0.265380  ...  0.022013  0.084425 -0.025749
# 4898 -0.092020 -0.314834 -0.059390  ...  0.040861 -0.107444 -0.026517
# 4899 -0.075271  0.071098  0.132797  ... -0.008341  0.144196  0.049182
#
#            761       762       763       764       765       766       767
# 0     0.375378  2.181348  0.200309 -0.032337  0.052605 -0.040100  0.027836
# 1     0.025111  0.743331 -0.354503 -0.183817  0.004248 -0.299750  0.208453
# 2     0.086167  1.876543 -0.075527  0.037005 -0.161844  0.032990 -0.084938
# 3     0.028809  0.727415 -0.026135 -0.125423 -0.069217 -0.018091  0.196489
# 4     0.126818  0.340276  0.082642 -0.326614  0.083827  0.098879 -0.004860
# ...        ...       ...       ...       ...       ...       ...       ...
# 4895  0.209613  1.086052 -0.137461  0.104048 -0.190715 -0.199413  0.060761
# 4896  0.262837  1.280039  0.025179  0.189111  0.057611 -0.116355  0.069078
# 4897  0.051514  1.549858 -0.029294  0.123250 -0.116112 -0.104490  0.078453
# 4898  0.397737  1.655661  0.100562 -0.027368  0.028118  0.168963  0.047645
# 4899  0.133712  1.539523 -0.020621  0.062832 -0.169064  0.002277  0.202563
#
# [4900 rows x 768 columns]

# %%
gpt_df.to_csv(pwd+"//Datasets//Nisha//FineTunedTransformers//gpt_base_finetuned_vectorized_Nisha_dataset.csv",index=False)
