# %%
# Importing Libraries
try:
    import pandas as pd
    import numpy as np
    from numpy import set_printoptions
    import os,sys
    import re
    # importing algorithms
    from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
    from sklearn.linear_model import LogisticRegression
    from sklearn import svm
    from sklearn.metrics import confusion_matrix, classification_report
    from sklearn.preprocessing import Normalizer
    from sklearn.preprocessing import StandardScaler
except Exception as e:
    print("Error is due to",e)
pwd = os.getcwd()
labels_df = pd.read_csv(pwd+"//Datasets//Nisha//Input//Nisha_dataset_labels.csv")

# %% [markdown]
# ## Verloop BERT Sentence Transformer

# %%
# V BERT vectorized data
x_df = pd.read_csv(pwd+"//Datasets//Nisha//SentenceTransformers//bert_vectorized_Nisha_dataset_vbert.csv")
y_df = labels_df['Labels']
# Test train split
x_train,x_test,y_train,y_test = train_test_split(x_df, y_df, test_size=0.30,random_state=21,stratify=y_df)

# Normalize scaling of train data
normalize_model = Normalizer()
nscaled_data_train = normalize_model.fit_transform(x_train)
# Normalize scaling of test data
nscaled_data_test = normalize_model.fit_transform(x_test)

# Standard scaling of train data
standard_model = StandardScaler()
sscaled_data_train = standard_model.fit_transform(x_train)
# Standard scaling of test data
sscaled_data_test = standard_model.fit_transform(x_test)

# %% [markdown]
# ### Hyperparameter Tuning for Normalized Data for SVM

# %%
# Random Search CV

# Set up the sample space
c_list = [0.1, 1, 10, 100, 1000]
gamma_list = ['scale', 1, 0.1, 0.01, 0.001, 0.0001]
kernel_list = ['poly','rbf']
# Create the grid
parameter_grid = {'C' : c_list, 'gamma' : gamma_list, 'kernel' : kernel_list}
# Define how many samples
number_models = 10
# Create a random search object
random_SVM_class = RandomizedSearchCV(estimator = svm.SVC(),
                                      param_distributions = parameter_grid,
                                      n_iter = number_models,
                                      scoring='accuracy',
                                      n_jobs=6,
                                      cv = 5,
                                      refit=True,
                                      return_train_score = True)
# Fit the object to our data
random_SVM_class.fit(nscaled_data_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(), n_jobs=6,
#                    param_distributions={'C': [0.1, 1, 10, 100, 1000],
#                                         'gamma': ['scale', 1, 0.1, 0.01, 0.001,
#                                                   0.0001],
#                                         'kernel': ['poly', 'rbf']},
#                    return_train_score=True, scoring='accuracy')

# %%
# print best parameter after tuning
print(random_SVM_class.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(random_SVM_class.best_estimator_)
# Out:
# {'kernel': 'rbf', 'gamma': 'scale', 'C': 1000}
# SVC(C=1000)

# %%
# Predicted test outputs
random_SVM_class_predictions = random_SVM_class.predict(nscaled_data_test)

#print Confusion Matrix
print(confusion_matrix(y_test,random_SVM_class_predictions))
 
# print Classification Report
print(classification_report(y_test, random_SVM_class_predictions))
# Out:
# [[176   2   0   1  25   6   0]
#  [  4 159   3   9  16  19   0]
#  [  0   4 198   7   1   0   0]
#  [  1  17   7 147  24  11   3]
#  [ 40   8   1  18 133   6   4]
#  [ 13  12   6  18   5 130  26]
#  [  0   0   0   0   3  24 183]]
#               precision    recall  f1-score   support
#
#            1       0.75      0.84      0.79       210
#            2       0.79      0.76      0.77       210
#            3       0.92      0.94      0.93       210
#            4       0.73      0.70      0.72       210
#            5       0.64      0.63      0.64       210
#            6       0.66      0.62      0.64       210
#            7       0.85      0.87      0.86       210
#
#     accuracy                           0.77      1470
#    macro avg       0.76      0.77      0.76      1470
# weighted avg       0.76      0.77      0.76      1470

# %%
# Examining results using pandas df
rand_cv_results_df = pd.DataFrame(random_SVM_class.cv_results_)
pd.set_option('display.max_columns', None)
rand_cv_results_df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0            0.824344            0.824708          0.822303         0.002674
# 1            0.529519            0.543003          0.537536         0.005584
# 2            0.678936            0.689140          0.682362         0.004619
# 3            0.998907            0.999636          0.998834         0.000483
# 4            0.643950            0.661443          0.654227         0.006161
# 5            0.529519            0.543003          0.537536         0.005584
# 6            0.529519            0.543003          0.537536         0.005584
# 7            0.457362            0.466472          0.463630         0.004087
# 8            0.818149            0.822157          0.818294         0.002866
# 9            0.529519            0.543003          0.537536         0.005584

# %%
# Grid Search CV

# Set up the sample space
c_list = [10, 100, 1000, 1500]
gamma_list = ['scale', 1, 0.01, 'auto', 0.0001]
kernel_list = ['poly','rbf']
# Create the grid
parameter_grid = {'C' : c_list, 'gamma' : gamma_list, 'kernel' : kernel_list}

# Create a grid search object
grid_SVM_class = GridSearchCV(estimator = svm.SVC(),
                             param_grid = parameter_grid,
                             scoring='accuracy',
                             n_jobs=4,
                             cv = 5,
                             refit=True,
                             return_train_score=True)

# Fit the object to our data
grid_SVM_class.fit(nscaled_data_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=4,
#              param_grid={'C': [10, 100, 1000, 1500],
#                          'gamma': ['scale', 1, 0.01, 'auto', 0.0001],
#                          'kernel': ['poly', 'rbf']},
#              return_train_score=True, scoring='accuracy')

# %%
# print best parameter after tuning
print(grid_SVM_class.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid_SVM_class.best_estimator_)
# Out:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# SVC(C=10)

# %%
# Predicted test outputs
grid_SVM_class_predictions = grid_SVM_class.predict(nscaled_data_test)

#print Confusion Matrix
print(confusion_matrix(y_test, grid_SVM_class_predictions))
 
# print Classification Report
print(classification_report(y_test, grid_SVM_class_predictions))
# Out:
# [[172   2   0   1  29   6   0]
#  [  5 157   3  15  13  17   0]
#  [  0   4 198   7   1   0   0]
#  [  1  14   7 149  25  12   2]
#  [ 37  11   1  17 134   6   4]
#  [ 11  12   6  14   7 136  24]
#  [  0   0   0   1   0  27 182]]
#               precision    recall  f1-score   support
#
#            1       0.76      0.82      0.79       210
#            2       0.79      0.75      0.77       210
#            3       0.92      0.94      0.93       210
#            4       0.73      0.71      0.72       210
#            5       0.64      0.64      0.64       210
#            6       0.67      0.65      0.66       210
#            7       0.86      0.87      0.86       210
#
#     accuracy                           0.77      1470
#    macro avg       0.77      0.77      0.77      1470
# weighted avg       0.77      0.77      0.77      1470

# %%
# Examining results using pandas df
grid_cv_results_df = pd.DataFrame(grid_SVM_class.cv_results_)
pd.set_option('display.max_columns', None)
grid_cv_results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        5.753491      0.331915         1.573140        0.043799      10
# 1        5.407392      1.107788         2.192500        0.215274      10
# 2        4.969010      0.067175         1.384329        0.129294      10
# 3        4.309068      0.842859         1.571857        0.374830      10
# 4       15.265203      0.846098         2.215762        0.312071      10
# 5        8.668946      0.825205         2.789878        0.296180      10
# 6       14.394090      1.402797         1.992663        0.175591      10
# 7       11.549268      1.841607         2.422702        0.493202      10
# 8       13.937065      0.630438         2.124614        0.055032      10
# 9       13.407571      1.838833         2.878743        0.238032      10
# 10       4.738477      0.327862         1.227997        0.055349     100
# 11       4.158703      0.754406         1.611693        0.290205     100
# 12       5.702853      1.364553         1.552365        0.288486     100
# 13       5.512445      1.443374         1.858428        0.250906     100
# 14      13.729116      1.479657         2.076309        0.156655     100
# 15       4.446063      0.544071         1.840470        0.315109     100
# 16      13.640506      1.612178         2.121736        0.083956     100
# 17       6.522486      1.054581         2.124885        0.305796     100
# 18      13.475518      1.369259         2.101317        0.063265     100
# 19      11.587812      1.862110         2.658952        0.542552     100
# 20       5.467705      0.512109         1.623982        0.089318    1000
# 21       5.128837      1.013079         1.953885        0.330539    1000
# 22       5.895814      0.401326         1.428501        0.049907    1000
# 23       5.059447      0.642128         1.886507        0.320210    1000
# 24      14.872407      1.817721         2.255276        0.109904    1000
# 25       4.402601      0.714288         1.859711        0.409965    1000
# 26      15.821592      2.111649         2.356267        0.277106    1000
# 27       4.446656      0.762079         1.804724        0.353317    1000
# 28      16.144491      0.865791         2.339997        0.099364    1000
# 29       7.976923      1.068296         2.382187        0.278844    1000
# 30       5.281436      0.723983         1.405092        0.115945    1500
# 31       4.538327      0.916965         1.812476        0.359100    1500
# 32       5.822828      1.115499         1.565721        0.053980    1500
# 33       5.453790      0.920471         2.065943        0.407751    1500
# 34      15.859238      0.606069         2.166055        0.171140    1500
# 35       4.212925      0.294033         1.982977        0.226776    1500
# 36      15.470837      2.164818         2.346416        0.182747    1500
# 37       4.982891      0.520991         2.036227        0.222472    1500
# 38      16.387853      1.297190         2.287520        0.052079    1500
# 39       7.660449      0.864595         2.231970        0.635450    1500
#
#    param_gamma param_kernel                                           params  \
# 0        scale         poly    {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 1        scale          rbf     {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 2            1         poly          {'C': 10, 'gamma': 1, 'kernel': 'poly'}
# 3            1          rbf           {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 4         0.01         poly       {'C': 10, 'gamma': 0.01, 'kernel': 'poly'}
# 5         0.01          rbf        {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 6         auto         poly     {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 7         auto          rbf      {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 8       0.0001         poly     {'C': 10, 'gamma': 0.0001, 'kernel': 'poly'}
# 9       0.0001          rbf      {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 10       scale         poly   {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}
# 11       scale          rbf    {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 12           1         poly         {'C': 100, 'gamma': 1, 'kernel': 'poly'}
# 13           1          rbf          {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 14        0.01         poly      {'C': 100, 'gamma': 0.01, 'kernel': 'poly'}
# 15        0.01          rbf       {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 16        auto         poly    {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}
# 17        auto          rbf     {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# 18      0.0001         poly    {'C': 100, 'gamma': 0.0001, 'kernel': 'poly'}
# 19      0.0001          rbf     {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 20       scale         poly  {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}
# 21       scale          rbf   {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 22           1         poly        {'C': 1000, 'gamma': 1, 'kernel': 'poly'}
# 23           1          rbf         {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 24        0.01         poly     {'C': 1000, 'gamma': 0.01, 'kernel': 'poly'}
# 25        0.01          rbf      {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 26        auto         poly   {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}
# 27        auto          rbf    {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}
# 28      0.0001         poly   {'C': 1000, 'gamma': 0.0001, 'kernel': 'poly'}
# 29      0.0001          rbf    {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 30       scale         poly  {'C': 1500, 'gamma': 'scale', 'kernel': 'poly'}
# 31       scale          rbf   {'C': 1500, 'gamma': 'scale', 'kernel': 'rbf'}
# 32           1         poly        {'C': 1500, 'gamma': 1, 'kernel': 'poly'}
# 33           1          rbf         {'C': 1500, 'gamma': 1, 'kernel': 'rbf'}
# 34        0.01         poly     {'C': 1500, 'gamma': 0.01, 'kernel': 'poly'}
# 24            0.544461            0.529519            0.543003
# 25            0.931122            0.937318            0.935860
# 26            0.544461            0.529519            0.543003
# 27            0.828353            0.834548            0.835641
# 28            0.544461            0.529519            0.543003
# 29            0.685131            0.676020            0.681487
# 30            0.998542            0.998907            0.999636
# 31            0.998542            0.998907            0.999636
# 32            0.998542            0.998907            0.999636
# 33            0.998542            0.998907            0.999636
# 34            0.544461            0.529519            0.543003
# 35            0.950073            0.956633            0.956268
# 36            0.544461            0.529519            0.543003
# 37            0.848761            0.855321            0.852405
# 38            0.544461            0.529519            0.543003
# 39            0.711006            0.698251            0.709913
#
#     mean_train_score  std_train_score
# 0           0.992566         0.000939
# 1           0.980394         0.001410
# 2           0.992566         0.000939
# 3           0.980394         0.001410
# 4           0.537536         0.005584
# 5           0.677915         0.004759
# 6           0.537536         0.005584
# 7           0.500510         0.002289
# 8           0.537536         0.005584
# 9           0.462682         0.003756
# 10          0.998834         0.000483
# 11          0.998834         0.000483
# 12          0.998834         0.000483
# 13          0.998834         0.000483
# 14          0.537536         0.005584
# 15          0.818513         0.002638
# 16          0.537536         0.005584
# 17          0.693367         0.004968
# 18          0.537536         0.005584
# 19          0.486880         0.001597
# 20          0.998834         0.000483
# 21          0.998834         0.000483
# 22          0.998834         0.000483
# 23          0.998834         0.000483
# 24          0.537536         0.005584
# 25          0.935860         0.002870
# 26          0.537536         0.005584
# 27          0.832143         0.002829
# 28          0.537536         0.005584
# 29          0.678353         0.004340
# 30          0.998834         0.000483
# 31          0.998834         0.000483
# 32          0.998834         0.000483
# 33          0.998834         0.000483
# 34          0.537536         0.005584
# 35          0.953936         0.002875
# 36          0.537536         0.005584
# 37          0.852332         0.002239
# 38          0.537536         0.005584
# 39          0.703790         0.005999

# %% [markdown]
# ### Hyperparameter Tuning for Standardized Data for SVM

# %%
# Random Search CV

# Set up the sample space
c_list = [0.1, 1, 10, 100, 1000]
gamma_list = ['scale', 1, 0.1, 0.01, 0.001, 0.0001]
kernel_list = ['poly','rbf']
# Create the grid
parameter_grid = {'C' : c_list, 'gamma' : gamma_list, 'kernel' : kernel_list}
# Define how many samples
number_models = 10
# Create a random search object
random_SVM_class = RandomizedSearchCV(estimator = svm.SVC(),
                                      param_distributions = parameter_grid,
                                      n_iter = number_models,
                                      scoring='accuracy',
                                      n_jobs=4,
                                      cv = 5,
                                      refit=True,
                                      return_train_score = True)
# Fit the object to our data
random_SVM_class.fit(sscaled_data_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(), n_jobs=4,
#                    param_distributions={'C': [0.1, 1, 10, 100, 1000],
#                                         'gamma': ['scale', 1, 0.1, 0.01, 0.001,
#                                                   0.0001],
#                                         'kernel': ['poly', 'rbf']},
#                    return_train_score=True, scoring='accuracy')

# %%
# print best parameter after tuning
print(random_SVM_class.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(random_SVM_class.best_estimator_)
# Out:
# {'kernel': 'rbf', 'gamma': 0.001, 'C': 100}
# SVC(C=100, gamma=0.001)

# %%
# Predicted test outputs
random_SVM_class_predictions = random_SVM_class.predict(sscaled_data_test)

#print Confusion Matrix
print(confusion_matrix(y_test,random_SVM_class_predictions))
 
# print Classification Report
print(classification_report(y_test, random_SVM_class_predictions))
# Out:
# [[174   1   0   1  23  11   0]
#  [  3 166   1  10  13  17   0]
#  [  0   5 196   6   1   2   0]
#  [  1  15   6 146  23  17   2]
#  [ 37  10   1  20 132   6   4]
#  [  8   9   4  15   4 144  26]
#  [  0   0   0   0   2  25 183]]
#               precision    recall  f1-score   support
#
#            1       0.78      0.83      0.80       210
#            2       0.81      0.79      0.80       210
#            3       0.94      0.93      0.94       210
#            4       0.74      0.70      0.72       210
#            5       0.67      0.63      0.65       210
#            6       0.65      0.69      0.67       210
#            7       0.85      0.87      0.86       210
#
#     accuracy                           0.78      1470
#    macro avg       0.78      0.78      0.78      1470
# weighted avg       0.78      0.78      0.78      1470

# %%
# Examining results using pandas df
rand_cv_results_df = pd.DataFrame(random_SVM_class.cv_results_)
pd.set_option('display.max_columns', None)
rand_cv_results_df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       9.504783      0.179258         2.110778        0.272688          rbf
# 1      12.352161      0.103670         1.706192        0.058039         poly
# 2       7.003580      0.871682         2.389738        0.473751          rbf
# 3      11.148078      1.275685         1.596993        0.200408         poly
# 4      10.156728      0.279719         1.778360        0.072881         poly
# 5      13.590011      2.817226         2.337441        0.242671          rbf
# 6      11.673988      1.879230         2.215981        0.405020          rbf
# 7       9.196647      1.401756         1.453363        0.159297         poly
# 8      11.031633      1.611932         2.474588        0.515784          rbf
# 9      11.180238      1.108051         1.640176        0.281858         poly
#
#   param_gamma param_C                                         params  \
# 0      0.0001       1     {'kernel': 'rbf', 'gamma': 0.0001, 'C': 1}
# 1           1     100       {'kernel': 'poly', 'gamma': 1, 'C': 100}
# 2       0.001     100    {'kernel': 'rbf', 'gamma': 0.001, 'C': 100}
# 3        0.01       1      {'kernel': 'poly', 'gamma': 0.01, 'C': 1}
# 4       0.001       1     {'kernel': 'poly', 'gamma': 0.001, 'C': 1}
# 5           1     0.1        {'kernel': 'rbf', 'gamma': 1, 'C': 0.1}
# 6           1     100        {'kernel': 'rbf', 'gamma': 1, 'C': 100}
# 7       0.001     100   {'kernel': 'poly', 'gamma': 0.001, 'C': 100}
# 8      0.0001     0.1   {'kernel': 'rbf', 'gamma': 0.0001, 'C': 0.1}
# 9      0.0001     100  {'kernel': 'poly', 'gamma': 0.0001, 'C': 100}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.698251           0.698251           0.667638           0.717201
# 1           0.723032           0.739067           0.721574           0.725948
# 2           0.728863           0.765306           0.759475           0.736152
# 3           0.723032           0.739067           0.721574           0.725948
# 4           0.664723           0.664723           0.631195           0.674927
# 5           0.355685           0.208455           0.240525           0.352770
# 6           0.290087           0.285714           0.306122           0.295918
# 7           0.723032           0.739067           0.721574           0.725948
# 8           0.568513           0.552478           0.534985           0.553936
# 9           0.469388           0.473761           0.402332           0.479592
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0           0.685131         0.693294        0.016404                5
# 1           0.714286         0.724781        0.008111                2
# 2           0.739067         0.745773        0.014091                1
# 3           0.714286         0.724781        0.008111                2
# 4           0.634111         0.653936        0.017796                6
# 5           0.221574         0.275802        0.064848               10
# 6           0.295918         0.294752        0.006862                9
# 7           0.714286         0.724781        0.008111                2
# 8           0.555394         0.553061        0.010696                7
# 9           0.444606         0.453936        0.028425                8
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0            0.727770            0.731050            0.735787
# 1            0.998907            0.998178            0.998542
# 2            0.998907            0.998178            0.998542
# 3            0.998907            0.998178            0.998542
# 4            0.822522            0.825802            0.820700
# 5            0.657434            0.515306            0.651968
# 6            0.998907            0.998178            0.998542
# 7            0.998907            0.998178            0.998542
# 8            0.558673            0.561589            0.568513
# 9            0.522595            0.503644            0.471210
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0            0.728499            0.736516          0.731924         0.003627
# 1            0.998907            0.999636          0.998834         0.000483
# 2            0.998907            0.999636          0.998834         0.000483
# 3            0.998907            0.999636          0.998834         0.000483
# 4            0.827259            0.820335          0.823324         0.002760
# 5            0.654155            0.659257          0.627624         0.056216
# 6            0.998907            0.999636          0.998834         0.000483
# 7            0.998907            0.999636          0.998834         0.000483
# 8            0.554665            0.568878          0.562464         0.005544
# 9            0.522959            0.491983          0.502478         0.019562

# %%
# Grid Search CV

# Set up the sample space
c_list = [1, 100, 1000]
gamma_list = ['auto', 'scale', 1, 0.001]
kernel_list = ['poly','rbf']
# Create the grid
parameter_grid = {'C' : c_list, 'gamma' : gamma_list, 'kernel' : kernel_list}

# Create a grid search object
grid_SVM_class = GridSearchCV(estimator = svm.SVC(),
                             param_grid = parameter_grid,
                             scoring='accuracy',
                             n_jobs=4,
                             cv = 5,
                             refit=True,
                             return_train_score=True)

# Fit the object to our data
grid_SVM_class.fit(sscaled_data_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=4,
#              param_grid={'C': [1, 100, 1000],
#                          'gamma': ['auto', 'scale', 1, 0.001],
#                          'kernel': ['poly', 'rbf']},
#              return_train_score=True, scoring='accuracy')

# %%
# print best parameter after tuning
print(grid_SVM_class.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid_SVM_class.best_estimator_)
# Out:
# {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# SVC(C=100, gamma='auto')

# %%
# Predicted test outputs
grid_SVM_class_predictions = grid_SVM_class.predict(sscaled_data_test)

#print Confusion Matrix
print(confusion_matrix(y_test, grid_SVM_class_predictions))
 
# print Classification Report
print(classification_report(y_test, grid_SVM_class_predictions))
# Out:
# [[174   1   0   1  25   9   0]
#  [  3 166   1  10  13  16   1]
#  [  0   5 195   7   1   2   0]
#  [  1  12   6 148  23  18   2]
#  [ 31  10   1  20 134   9   5]
#  [  6   9   4  14   3 148  26]
#  [  0   0   0   0   1  24 185]]
#               precision    recall  f1-score   support
#
#            1       0.81      0.83      0.82       210
#            2       0.82      0.79      0.80       210
#            3       0.94      0.93      0.94       210
#            4       0.74      0.70      0.72       210
#            5       0.67      0.64      0.65       210
#            6       0.65      0.70      0.68       210
#            7       0.84      0.88      0.86       210
#
#     accuracy                           0.78      1470
#    macro avg       0.78      0.78      0.78      1470
# weighted avg       0.78      0.78      0.78      1470

# %%
# Examining results using pandas df
grid_cv_results_df = pd.DataFrame(grid_SVM_class.cv_results_)
pd.set_option('display.max_columns', None)
grid_cv_results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0
# 13          0.998834         0.000483
# 14          0.998834         0.000483
# 15          0.998834         0.000483
# 16          0.998834         0.000483
# 17          0.998834         0.000483
# 18          0.998834         0.000483
# 19          0.998834         0.000483
# 20          0.998834         0.000483
# 21          0.998834         0.000483
# 22          0.998834         0.000483
# 23          0.998834         0.000483

# %% [markdown]
# ## XLM Base Sentence Transformer

# %%
# XLM Base vectorized data
x_df = pd.read_csv(pwd+"//Datasets//Nisha//SentenceTransformers//xlm_vectorized_Nisha_dataset.csv")
y_df = labels_df['Labels']
# Test train split
x_train,x_test,y_train,y_test = train_test_split(x_df, y_df, test_size=0.30,random_state=21,stratify=y_df)

# Normalize scaling of train data
normalize_model = Normalizer()
nscaled_data_train = normalize_model.fit_transform(x_train)
# Normalize scaling of test data
nscaled_data_test = normalize_model.fit_transform(x_test)

# Standard scaling of train data
standard_model = StandardScaler()
sscaled_data_train = standard_model.fit_transform(x_train)
# Standard scaling of test data
sscaled_data_test = standard_model.fit_transform(x_test)

# %% [markdown]
# ### Hyperparameter Tuning for Normalized Data for SVM

# %%
# Random Search CV

# Set up the sample space
c_list = [0.1, 1, 10, 100, 1000]
gamma_list = ['scale', 1, 0.1, 0.01, 0.001, 0.0001]
kernel_list = ['poly','rbf']
# Create the grid
parameter_grid = {'C' : c_list, 'gamma' : gamma_list, 'kernel' : kernel_list}
# Define how many samples
number_models = 10
# Create a random search object
random_SVM_class = RandomizedSearchCV(estimator = svm.SVC(),
                                      param_distributions = parameter_grid,
                                      n_iter = number_models,
                                      scoring='accuracy',
                                      n_jobs=6,
                                      cv = 5,
                                      refit=True,
                                      return_train_score = True)
# Fit the object to our data
random_SVM_class.fit(nscaled_data_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(), n_jobs=6,
#                    param_distributions={'C': [0.1, 1, 10, 100, 1000],
#                                         'gamma': ['scale', 1, 0.1, 0.01, 0.001,
#                                                   0.0001],
#                                         'kernel': ['poly', 'rbf']},
#                    return_train_score=True, scoring='accuracy')

# %%
# print best parameter after tuning
print(random_SVM_class.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(random_SVM_class.best_estimator_)
# Out:
# {'kernel': 'rbf', 'gamma': 0.1, 'C': 100}
# SVC(C=100, gamma=0.1)

# %%
# Predicted test outputs
random_SVM_class_predictions = random_SVM_class.predict(nscaled_data_test)

#print Confusion Matrix
print(confusion_matrix(y_test,random_SVM_class_predictions))
 
# print Classification Report
print(classification_report(y_test, random_SVM_class_predictions))
# Out:
# [[165   0   2   4  29   9   1]
#  [  2 176   2  10  11   9   0]
#  [  0   6 200   1   1   2   0]
#  [  7  14   5 139  22  18   5]
#  [ 22  19   0  16 147   2   4]
#  [ 17  15   1  15   5 131  26]
#  [  0   0   0   3   2  23 182]]
#               precision    recall  f1-score   support
#
#            1       0.77      0.79      0.78       210
#            2       0.77      0.84      0.80       210
#            3       0.95      0.95      0.95       210
#            4       0.74      0.66      0.70       210
#            5       0.68      0.70      0.69       210
#            6       0.68      0.62      0.65       210
#            7       0.83      0.87      0.85       210
#
#     accuracy                           0.78      1470
#    macro avg       0.77      0.78      0.77      1470
# weighted avg       0.77      0.78      0.77      1470

# %%
# Examining results using pandas df
rand_cv_results_df = pd.DataFrame(random_SVM_class.cv_results_)
pd.set_option('display.max_columns', None)
rand_cv_results_df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0      11.004129      0.151427         3.161042        0.106436          rbf
# 1      23.180659      1.130293         4.667195        0.185433          rbf
# 2      21.842375      2.299392         3.027818        0.361588         poly
# 3      10.812370      0.268926         2.265899        0.050595         poly
# 4       6.750270      0.476048         3.062911        0.173070          rbf
# 5       8.943895      0.903794         2.220976        0.156999         poly
# 6      10.481988      0.194233         2.434031        0.081890         poly
# 7      15.039896      0.206988         2.849330        0.068872         poly
# 8      24.057638      0.408429         3.278316        0.049877         poly
# 9      20.901752      2.053305         2.658303        0.343879         poly
#
#   param_gamma param_C                                           params  \
# 0           1      10           {'kernel': 'rbf', 'gamma': 1, 'C': 10}
# 1       0.001     0.1      {'kernel': 'rbf', 'gamma': 0.001, 'C': 0.1}
# 2        0.01    1000     {'kernel': 'poly', 'gamma': 0.01, 'C': 1000}
# 3       scale    1000  {'kernel': 'poly', 'gamma': 'scale', 'C': 1000}
# 4         0.1     100        {'kernel': 'rbf', 'gamma': 0.1, 'C': 100}
# 5         0.1    1000      {'kernel': 'poly', 'gamma': 0.1, 'C': 1000}
# 6       scale       1     {'kernel': 'poly', 'gamma': 'scale', 'C': 1}
# 7         0.1     100       {'kernel': 'poly', 'gamma': 0.1, 'C': 100}
# 8      0.0001      10     {'kernel': 'poly', 'gamma': 0.0001, 'C': 10}
# 9        0.01       1        {'kernel': 'poly', 'gamma': 0.01, 'C': 1}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.731778           0.721574           0.747813           0.734694
# 1           0.529155           0.498542           0.507289           0.504373
# 2           0.584548           0.523324           0.567055           0.537901
# 3           0.711370           0.702624           0.723032           0.714286
# 4           0.727405           0.737609           0.766764           0.739067
# 5           0.728863           0.712828           0.737609           0.718659
# 6           0.728863           0.712828           0.737609           0.717201
# 7           0.674927           0.629738           0.657434           0.628280
# 8           0.584548           0.523324           0.567055           0.537901
# 9           0.584548           0.523324           0.567055           0.537901
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0           0.736152         0.734402        0.008420                2
# 1           0.501458         0.508163        0.010893               10
# 2           0.505831         0.543732        0.028625                7
# 3           0.712828         0.712828        0.006519                5
# 4           0.725948         0.739359        0.014676                1
# 5           0.727405         0.725073        0.008580                3
# 6           0.728863         0.725073        0.008920                3
# 7           0.616618         0.641399        0.021464                6
# 8           0.505831         0.543732        0.028625                7
# 9           0.505831         0.543732        0.028625                7
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0            0.987609            0.986516            0.983236
# 1            0.511297            0.514577            0.520773
# 2            0.563047            0.567055            0.555758
# 3            0.998542            0.997813            0.997813
# 4            0.939504            0.940598            0.937318
# 5            0.876093            0.873542            0.873907
# 6            0.877187            0.873542            0.874271
# 7            0.675292            0.679300            0.672741
# 8            0.563047            0.567055            0.555758
# 9            0.563047            0.567055            0.555758
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0            0.988703            0.988703          0.986953         0.002028
# 1            0.510933            0.517128          0.514942         0.003695
# 2            0.558309            0.564140          0.561662         0.004080
# 3            0.997813            0.998907          0.998178         0.000461
# 4            0.943878            0.939869          0.940233         0.002125
# 5            0.877551            0.880466          0.876312         0.002542
# 6            0.878280            0.880466          0.876749         0.002560
# 7            0.680029            0.680758          0.677624         0.003089
# 8            0.558309            0.564140          0.561662         0.004080
# 9            0.558309            0.564140          0.561662         0.004080

# %%
# Grid Search CV

# Set up the sample space
c_list = [1, 10, 100, 1000]
gamma_list = ['scale', 1, 0.01, 'auto', 0.1]
kernel_list = ['poly','rbf']
# Create the grid
parameter_grid = {'C' : c_list, 'gamma' : gamma_list, 'kernel' : kernel_list}

# Create a grid search object
grid_SVM_class = GridSearchCV(estimator = svm.SVC(),
                             param_grid = parameter_grid,
                             scoring='accuracy',
                             n_jobs=4,
                             cv = 5,
                             refit=True,
                             return_train_score=True)

# Fit the object to our data
grid_SVM_class.fit(nscaled_data_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=4,
#              param_grid={'C': [1, 10, 100, 1000],
#                          'gamma': ['scale', 1, 0.01, 'auto', 0.1],
#                          'kernel': ['poly', 'rbf']},
#              return_train_score=True, scoring='accuracy')

# %%
# print best parameter after tuning
print(grid_SVM_class.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid_SVM_class.best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# SVC(C=100, gamma=0.1)

# %%
# Predicted test outputs
grid_SVM_class_predictions = grid_SVM_class.predict(nscaled_data_test)

#print Confusion Matrix
print(confusion_matrix(y_test, grid_SVM_class_predictions))
 
# print Classification Report
print(classification_report(y_test, grid_SVM_class_predictions))
# Out:
# [[165   0   2   4  29   9   1]
#  [  2 176   2  10  11   9   0]
#  [  0   6 200   1   1   2   0]
#  [  7  14   5 139  22  18   5]
#  [ 22  19   0  16 147   2   4]
#  [ 17  15   1  15   5 131  26]
#  [  0   0   0   3   2  23 182]]
#               precision    recall  f1-score   support
#
#            1       0.77      0.79      0.78       210
#            2       0.77      0.84      0.80       210
#            3       0.95      0.95      0.95       210
#            4       0.74      0.66      0.70       210
#            5       0.68      0.70      0.69       210
#            6       0.68      0.62      0.65       210
#            7       0.83      0.87      0.85       210
#
#     accuracy                           0.78      1470
#    macro avg       0.77      0.78      0.77      1470
# weighted avg       0.77      0.78      0.77      1470

# %%
# Examining results using pandas df
grid_cv_results_df = pd.DataFrame(grid_SVM_class.cv_results_)
pd.set_option('display.max_columns', None)
grid_cv_results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       10.183722      1.286308         1.767655        0.131099       1
# 1        6.736775      0.824237         2.942212        0.090167       1
# 2        6.853639      0.220500         1.657744        0.074668       1
# 3        6.112369      0.655145         2.883020        0.215575       1
# 4       16.226067      0.820841         2.399957        0.095237       1
# 5       13.255779      1.660735         4.059981        0.233839       1
# 6       15.806314      1.108836         2.345320        0.126702       1
# 7       15.597828      1.635849         3.950140        0.122452       1
# 8       16.029038      0.779231         2.346178        0.120335       1
# 9        8.012041      0.721659         3.506210        0.222596       1
# 10       7.066554      0.605862         1.691354        0.146278      10
# 11       6.614501      0.685672         2.856139        0.152181      10
# 12       7.461769      0.071766         1.722280        0.080557      10
# 13       6.345427      0.669622         2.851590        0.091324      10
# 14      16.153724      1.189809         2.440150        0.048121      10
# 15       8.064224      0.913761         3.280891        0.178514      10
# 16      16.005335      1.279434         2.361024        0.113028      10
# 17      12.249621      1.190699         3.985756        0.278277      10
# 18      15.589238      0.768068         2.227441        0.098405      10
# 19       5.650236      0.331321         2.747449        0.145398      10
# 20       7.272185      0.479600         1.620923        0.155710     100
# 21       6.833308      0.467049         2.846084        0.147937     100
# 22       7.327161      0.395980         1.640575        0.077119     100
# 23       6.443327      0.817696         2.863543        0.138918     100
# 24      15.780896      1.543993         2.419039        0.102300     100
# 25       5.289048      0.424239         2.862523        0.194386     100
# 26      21.337600      1.556314         2.806654        0.308537     100
# 27       7.699546      1.630675         3.322900        0.092657     100
# 28       9.311130      0.652675         1.994658        0.120147     100
# 29       4.825135      0.439482         2.475733        0.140425     100
# 30       7.050609      0.661787         1.700817        0.099062    1000
# 31       6.520469      0.655245         2.841624        0.196476    1000
# 32       7.197774      0.267865         1.678271        0.042620    1000
# 33       6.328004      0.696837         2.750424        0.179338    1000
# 34      16.009235      1.160976         2.283331        0.125967    1000
# 35       4.750395      0.542040         2.439551        0.160691    1000
# 36      15.912611      1.148553         2.398797        0.101975    1000
# 37       4.858186      0.567025         2.656722        0.070737    1000
# 38       6.778560      0.555840         1.673176        0.102666    1000
# 39       4.843618      0.464819         2.433969        0.259096    1000
#
#    param_gamma param_kernel                                           params  \
# 0        scale         poly     {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 1        scale          rbf      {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 2            1         poly           {'C': 1, 'gamma': 1, 'kernel': 'poly'}
# 3            1          rbf            {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 4         0.01         poly        {'C': 1, 'gamma': 0.01, 'kernel': 'poly'}
# 5         0.01          rbf         {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 6         auto         poly      {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 7         auto          rbf       {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 8          0.1         poly         {'C': 1, 'gamma': 0.1, 'kernel': 'poly'}
# 9          0.1          rbf          {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 10       scale         poly    {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 11       scale          rbf     {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 12           1         poly          {'C': 10, 'gamma': 1, 'kernel': 'poly'}
# 13           1          rbf           {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 14        0.01         poly       {'C': 10, 'gamma': 0.01, 'kernel': 'poly'}
# 15        0.01          rbf        {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 16        auto         poly     {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 17        auto          rbf      {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 18         0.1         poly        {'C': 10, 'gamma': 0.1, 'kernel': 'poly'}
# 19         0.1          rbf         {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 20       scale         poly   {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}
# 21       scale          rbf    {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 22           1         poly         {'C': 100, 'gamma': 1, 'kernel': 'poly'}
# 23           1          rbf          {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 24        0.01         poly      {'C': 100, 'gamma': 0.01, 'kernel': 'poly'}
# 25        0.01          rbf       {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 26        auto         poly    {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}
# 27        auto          rbf     {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# 28         0.1         poly       {'C': 100, 'gamma': 0.1, 'kernel': 'poly'}
# 29         0.1          rbf        {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 30       scale         poly  {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}
# 31       scale          rbf   {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 32           1         poly        {'C': 1000, 'gamma': 1, 'kernel': 'poly'}
# 33           1          rbf         {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 34        0.01         poly     {'C': 1000, 'gamma': 0.01, 'kernel': 'poly'}
# 35        0.01          rbf      {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 36        auto         poly   {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}
# 37        auto          rbf    {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}
# 38         0.1         poly      {'C': 1000, 'gamma': 0.1, 'kernel': 'poly'}
# 39         0.1          rbf       {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0
#
#     mean_train_score  std_train_score
# 0           0.876749         0.002560
# 1           0.833236         0.004114
# 2           0.876312         0.002542
# 3           0.833090         0.003891
# 4           0.561662         0.004080
# 5           0.542493         0.006323
# 6           0.561662         0.004080
# 7           0.514942         0.003695
# 8           0.561662         0.004080
# 9           0.691181         0.000818
# 10          0.992274         0.000989
# 11          0.986953         0.002028
# 12          0.992274         0.000989
# 13          0.986953         0.002028
# 14          0.561662         0.004080
# 15          0.692274         0.002402
# 16          0.561662         0.004080
# 17          0.564359         0.004749
# 18          0.560058         0.002901
# 19          0.806487         0.004621
# 20          0.998032         0.000592
# 21          0.997741         0.000707
# 22          0.998032         0.000592
# 23          0.997741         0.000707
# 24          0.561662         0.004080
# 25          0.797522         0.005559
# 26          0.561662         0.004080
# 27          0.703790         0.003287
# 28          0.677624         0.003089
# 29          0.940233         0.002125
# 30          0.998178         0.000461
# 31          0.998178         0.000461
# 32          0.998178         0.000461
# 33          0.998178         0.000461
# 34          0.561662         0.004080
# 35          0.914286         0.004743
# 36          0.561662         0.004080
# 37          0.807507         0.005015
# 38          0.876312         0.002542
# 39          0.996574         0.000881

# %% [markdown]
# ### Hyperparameter Tuning for Standardized Data for SVM

# %%
# Random Search CV

# Set up the sample space
c_list = [0.1, 1, 10, 100, 1000]
gamma_list = ['scale', 1, 0.1, 0.01, 0.001, 0.0001]
kernel_list = ['poly','rbf']
# Create the grid
parameter_grid = {'C' : c_list, 'gamma' : gamma_list, 'kernel' : kernel_list}
# Define how many samples
number_models = 10
# Create a random search object
random_SVM_class = RandomizedSearchCV(estimator = svm.SVC(),
                                      param_distributions = parameter_grid,
                                      n_iter = number_models,
                                      scoring='accuracy',
                                      n_jobs=4,
                                      cv = 5,
                                      refit=True,
                                      return_train_score = True)
# Fit the object to our data
random_SVM_class.fit(sscaled_data_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(), n_jobs=4,
#                    param_distributions={'C': [0.1, 1, 10, 100, 1000],
#                                         'gamma': ['scale', 1, 0.1, 0.01, 0.001,
#                                                   0.0001],
#                                         'kernel': ['poly', 'rbf']},
#                    return_train_score=True, scoring='accuracy')

# %%
# print best parameter after tuning
print(random_SVM_class.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(random_SVM_class.best_estimator_)
# Out:
# {'kernel': 'rbf', 'gamma': 0.001, 'C': 100}
# SVC(C=100, gamma=0.001)

# %%
# Predicted test outputs
random_SVM_class_predictions = random_SVM_class.predict(sscaled_data_test)

#print Confusion Matrix
print(confusion_matrix(y_test,random_SVM_class_predictions))
 
# print Classification Report
print(classification_report(y_test, random_SVM_class_predictions))
# Out:
# [[165   1   1   2  28  11   2]
#  [  3 173   2  11  11   9   1]
#  [  0   2 198   2   3   5   0]
#  [  5  16   6 140  20  19   4]
#  [ 26  16   1  17 142   3   5]
#  [ 13  12   6  25   6 120  28]
#  [  2   0   0   3   1  37 167]]
#               precision    recall  f1-score   support
#
#            1       0.77      0.79      0.78       210
#            2       0.79      0.82      0.80       210
#            3       0.93      0.94      0.93       210
#            4       0.70      0.67      0.68       210
#            5       0.67      0.68      0.67       210
#            6       0.59      0.57      0.58       210
#            7       0.81      0.80      0.80       210
#
#     accuracy                           0.75      1470
#    macro avg       0.75      0.75      0.75      1470
# weighted avg       0.75      0.75      0.75      1470

# %%
# Examining results using pandas df
rand_cv_results_df = pd.DataFrame(random_SVM_class.cv_results_)
pd.set_option('display.max_columns', None)
rand_cv_results_df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0      17.294074      0.346323         3.318343        0.261250          rbf
# 1      14.585748      0.603529         2.254558        0.061661         poly
# 2      14.858489      1.001227         3.439198        0.175269          rbf
# 3       6.005717      0.258414         2.750823        0.170681          rbf
# 4       9.232998      0.399718         3.448628        0.182796          rbf
# 5       8.391319      0.882139         1.710719        0.153978         poly
# 6       9.831820      0.472705         1.823652        0.067348         poly
# 7      17.284958      0.260249         2.463653        0.082660         poly
# 8       9.056742      0.204433         1.765525        0.030420         poly
# 9      14.622053      2.012980         3.301801        0.408795          rbf
#
#   param_gamma param_C                                        params  \
# 0         0.1      10      {'kernel': 'rbf', 'gamma': 0.1, 'C': 10}
# 1       0.001     0.1  {'kernel': 'poly', 'gamma': 0.001, 'C': 0.1}
# 2        0.01      10     {'kernel': 'rbf', 'gamma': 0.01, 'C': 10}
# 3       0.001     100   {'kernel': 'rbf', 'gamma': 0.001, 'C': 100}
# 4       0.001     0.1   {'kernel': 'rbf', 'gamma': 0.001, 'C': 0.1}
# 5        0.01     100   {'kernel': 'poly', 'gamma': 0.01, 'C': 100}
# 6       scale       1  {'kernel': 'poly', 'gamma': 'scale', 'C': 1}
# 7      0.0001      10  {'kernel': 'poly', 'gamma': 0.0001, 'C': 10}
# 8         0.1       1      {'kernel': 'poly', 'gamma': 0.1, 'C': 1}
# 9        0.01    1000   {'kernel': 'rbf', 'gamma': 0.01, 'C': 1000}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.317784           0.322157           0.330904           0.325073
# 1           0.507289           0.483965           0.510204           0.517493
# 2           0.591837           0.542274           0.600583           0.558309
# 3           0.706997           0.698251           0.728863           0.714286
# 4           0.672012           0.618076           0.651603           0.634111
# 5           0.667638           0.690962           0.677843           0.667638
# 6           0.709913           0.692420           0.705539           0.688047
# 7           0.482507           0.478134           0.467930           0.502915
# 8           0.667638           0.690962           0.677843           0.667638
# 9           0.590379           0.542274           0.600583           0.551020
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0           0.320700         0.323324        0.004460               10
# 1           0.529155         0.509621        0.014883                8
# 2           0.568513         0.572303        0.021416                6
# 3           0.708455         0.711370        0.010141                1
# 4           0.626822         0.640525        0.019220                5
# 5           0.651603         0.671137        0.012993                3
# 6           0.695335         0.698251        0.008194                2
# 7           0.475219         0.481341        0.011785                9
# 8           0.651603         0.671137        0.012993                3
# 9           0.565598         0.569971        0.022356                7
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0            0.998907            0.997813            0.998178
# 1            0.546647            0.545190            0.538265
# 2            0.998542            0.997813            0.997813
# 3            0.998542            0.997813            0.997813
# 4            0.669461            0.671647            0.667274
# 5            0.998907            0.998178            0.998542
# 6            0.886662            0.879009            0.876093
# 7            0.523324            0.522959            0.489431
# 8            0.998907            0.998178            0.998542
# 9            0.998907            0.998178            0.998542
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0            0.998542            0.999636          0.998615         0.000627
# 1            0.546647            0.563047          0.547959         0.008157
# 2            0.997449            0.998907          0.998105         0.000536
# 3            0.997449            0.998907          0.998105         0.000536
# 4            0.676020            0.673834          0.671647         0.003092
# 5            0.998907            0.999636          0.998834         0.000483
# 6            0.883746            0.887755          0.882653         0.004463
# 7            0.529883            0.514942          0.516108         0.014155
# 8            0.998907            0.999636          0.998834         0.000483
# 9            0.998907            0.999636          0.998834         0.000483

# %%
# Grid Search CV

# Set up the sample space
c_list = [1, 100, 1000]
gamma_list = ['auto', 'scale', 0.1, 0.001]
kernel_list = ['poly','rbf']
# Create the grid
parameter_grid = {'C' : c_list, 'gamma' : gamma_list, 'kernel' : kernel_list}

# Create a grid search object
grid_SVM_class = GridSearchCV(estimator = svm.SVC(),
                             param_grid = parameter_grid,
                             scoring='accuracy',
                             n_jobs=4,
                             cv = 5,
                             refit=True,
                             return_train_score=True)

# Fit the object to our data
grid_SVM_class.fit(sscaled_data_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=4,
#              param_grid={'C': [1, 100, 1000],
#                          'gamma': ['auto', 'scale', 0.1, 0.001],
#                          'kernel': ['poly', 'rbf']},
#              return_train_score=True, scoring='accuracy')

# %%
# print best parameter after tuning
print(grid_SVM_class.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid_SVM_class.best_estimator_)
# Out:
# {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# SVC(C=1, gamma='auto')

# %%
# Predicted test outputs
grid_SVM_class_predictions = grid_SVM_class.predict(sscaled_data_test)

#print Confusion Matrix
print(confusion_matrix(y_test, grid_SVM_class_predictions))
 
# print Classification Report
print(classification_report(y_test, grid_SVM_class_predictions))
# Out:
# [[153   2   1   4  31  16   3]
#  [  2 176   1   6   8  15   2]
#  [  0   4 194   6   1   5   0]
#  [  2  10   5 139  18  34   2]
#  [ 15  16   0  15 152   6   6]
#  [  3   9   2  16   1 140  39]
#  [  0   0   0   0   1  23 186]]
#               precision    recall  f1-score   support
#
#            1       0.87      0.73      0.79       210
#            2       0.81      0.84      0.82       210
#            3       0.96      0.92      0.94       210
#            4       0.75      0.66      0.70       210
#            5       0.72      0.72      0.72       210
#            6       0.59      0.67      0.62       210
#            7       0.78      0.89      0.83       210
#
#     accuracy                           0.78      1470
#    macro avg       0.78      0.78      0.78      1470
# weighted avg       0.78      0.78      0.78      1470

# %%
# Examining results using pandas df
grid_cv_results_df = pd.DataFrame(grid_SVM_class.cv_results_)
pd.set_option('display.max_columns', None)
grid_cv_results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        9.286546      0.219652         1.825532        0.175455       1
# 1        7.416618      0.988916         3.008729        0.041780       1
# 2        8.925111      0.141015         1.786657        0.126570       1
# 3        7.004805      0.778547         2.875309        0.227295       1
# 4        8.582564      0.551211         1.694825        0.092843       1
# 5       14.897037      1.230626         3.596071        0.220980       1
# 6        9.378368      0.490247         1.818892        0.059850       1
# 7        6.391293      0.742179         2.985149        0.189710       1
# 8        9.107201      0.934903         1.636532        0.132484     100
# 9        7.189059      0.751401         2.932274        0.238518     100
# 10       8.533276      0.684781         1.682436        0.070271     100
# 11       7.436377      0.792080         2.866189        0.186735     100
# 12       8.291356      0.604000         1.645002        0.150227     100
# 13      15.291546      0.930897         3.546646        0.187558     100
# 14       8.510206      0.154321         1.627527        0.080960     100
# 15       6.493217      0.744280         2.819256        0.246850     100
# 16       8.633376      0.394641         1.647879        0.054708    1000
# 17       7.317773      0.888065         2.949268        0.121304    1000
# 18       8.381924      0.598877         1.648471        0.179866    1000
# 19       7.340326      0.794715         2.896395        0.100251    1000
# 20       8.498276      0.492063         1.700908        0.035628    1000
# 21      14.434944      1.142034         3.558666        0.167438    1000
# 22       8.248413      0.512220         1.612302        0.032413    1000
# 23       6.313837      1.083146         2.682423        0.258847    1000
#
#    param_gamma param_kernel                                           params  \
# 0         auto         poly      {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 1         auto          rbf       {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 2        scale         poly     {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 3        scale          rbf      {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 4          0.1         poly         {'C': 1, 'gamma': 0.1, 'kernel': 'poly'}
# 5          0.1          rbf          {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 6        0.001         poly       {'C': 1, 'gamma': 0.001, 'kernel': 'poly'}
# 7        0.001          rbf        {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 8         auto         poly    {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}
# 9         auto          rbf     {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# 10       scale         poly   {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}
# 11       scale          rbf    {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 12         0.1         poly       {'C': 100, 'gamma': 0.1, 'kernel': 'poly'}
# 13         0.1          rbf        {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 14       0.001         poly     {'C': 100, 'gamma': 0.001, 'kernel': 'poly'}
# 15       0.001          rbf      {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 16        auto         poly   {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}
# 17        auto          rbf    {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}
# 18       scale         poly  {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}
# 19       scale          rbf   {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 20         0.1         poly      {'C': 1000, 'gamma': 0.1, 'kernel': 'poly'}
# 21         0.1          rbf       {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 22       0.001         poly    {'C': 1000, 'gamma': 0.001, 'kernel': 'poly'}
# 23       0.001          rbf     {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.711370           0.692420           0.705539
# 1            0.739067           0.708455           0.725948
# 2            0.709913           0.692420           0.705539
# 3            0.739067           0.708455           0.725948
# 4            0.667638           0.690962           0.677843
# 5            0.313411           0.317784           0.327988
# 6            0.682216           0.644315           0.677843
# 7            0.734694           0.706997           0.725948
# 8            0.669096           0.693878           0.683673
# 9            0.717201           0.699708           0.728863
# 10           0.669096           0.693878           0.683673
# 11           0.717201           0.699708           0.728863
# 12           0.667638           0.690962           0.677843
# 13           0.317784           0.322157           0.330904
# 14           0.679300           0.689504           0.686589
# 15           0.706997           0.698251           0.728863
# 16           0.667638           0.690962           0.683673
# 17           0.711370           0.699708           0.721574
# 18           0.667638           0.690962           0.683673
# 19           0.711370           0.699708           0.721574
# 20           0.667638           0.690962           0.677843
# 21           0.317784           0.322157           0.330904
# 22           0.669096           0.690962           0.683673
# 23           0.701166           0.699708           0.721574
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.688047           0.695335         0.698542        0.008619
# 1            0.724490           0.731778         0.725948        0.010141
# 2            0.688047           0.695335         0.698251        0.008194
# 3            0.724490           0.731778         0.725948        0.010141
# 4            0.667638           0.651603         0.671137        0.012993
# 5            0.320700           0.313411         0.318659        0.005423
# 6            0.670554           0.669096         0.668805        0.013149
# 7            0.715743           0.718659         0.720408        0.009375
# 8            0.679300           0.667638         0.678717        0.009696
# 9            0.723032           0.705539         0.714869        0.010815
# 10           0.679300           0.667638         0.678717        0.009696
# 11           0.723032           0.705539         0.714869        0.010815
