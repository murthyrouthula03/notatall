# %%
try:
    import os, sys
    import pandas as pd
    import seaborn as sns
    import matplotlib.pyplot as plt
    import numpy as np
except Exception as e:
    print("Error due to", e)

# %%
pwd = os.getcwd()
# Reading preprocessing file
kb_df = pd.read_csv(pwd+"//Datasets//Nisha//Input//nisha_preprocessing.csv",encoding_errors='ignore')
kb_df
# Out:
#                               id  \
# 0     Ugz7LQV0ZWpuNnjBaxJ4AaABAg
# 1     UgxvWJ_kJL2nePTkg2N4AaABAg
# 2     UgxxeUmiH9f8XOZZWr14AaABAg
# 3     Ugz-UPvwHMx4nSKVoCB4AaABAg
# 4     UgzfXhbesBABQzi4-m94AaABAg
# ...                          ...
# 4895  UgyGSYkiLHY3dWl4AZt4AaABAg
# 4896  Ugzx3OSiIndEsUN54IB4AaABAg
# 4897  UgxRwq2MsR9csHLc7MJ4AaABAg
# 4898  UgxxO1vtL-g7PPRVXBp4AaABAg
# 4899  UgyNWcXDvbZF1I7S8rh4AaABAg
#
#                                             commentText  Labels  stopwords  \
# 0                                 love potato ke prathe       2          1
# 1     wwaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaww       3          0
# 2                                                  nice       3          0
# 3                                           wow amazing       3          0
# 4                                           thank madam       1          1
# ...                                                 ...     ...        ...
# 4895  mam kya hum butter ki bjaye desi ghee bhi daal...       7          0
# 4896  ky hum condensed milk k jagha par amul powder ...       7          0
# 4897  very yummy cake mamcondensed milk k jagah aur ...       5          0
# 4898  mad aapne powder sugar condensed milk dono kyu...       7          2
# 4899  cake microwave oven se nikalne k baad thodi de...       7          1
#
#       upper  hastags  word_count  char_count   avg_word  numerics
# 0         0        0           4          21   4.500000         0
# 1         0        0           1          49  49.000000         0
# 2         0        0           1           4   4.000000         0
# 3         0        0           2          11   5.000000         0
# 4         0        0           2          11   5.000000         0
# ...     ...      ...         ...         ...        ...       ...
# 4895      0        0          12          55   3.666667         0
# 4896      0        0          12          56   3.750000         0
# 4897      0        0          15          79   4.333333         0
# 4898      0        0          11          56   4.600000         0
# 4899      0        0          14          68   3.928571         0
#
# [4900 rows x 10 columns]

# %%
# info of data
kb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4900 entries, 0 to 4899
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4900 non-null   object
#  1   commentText  4900 non-null   object
#  2   Labels       4900 non-null   int64
#  3   stopwords    4900 non-null   int64
#  4   upper        4900 non-null   int64
#  5   hastags      4900 non-null   int64
#  6   word_count   4900 non-null   int64
#  7   char_count   4900 non-null   int64
#  8   avg_word     4900 non-null   float64
#  9   numerics     4900 non-null   int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 382.9+ KB

# %% [markdown]
# commentText is Nominal categorical data as there is no natural order and are just comments.
#
# Labels, stopwords, upper, hashtags, word_count, char_count, numerics are the info of number of their presence in comments. It is Discrete Numerical data.
#
# avg_word is (char_count - spaces)/word_count. It is Continuous Numerical data.

# %%
# checking null values
kb_df.isnull().sum()
# Out:
# id             0
# commentText    0
# Labels         0
# stopwords      0
# upper          0
# hastags        0
# word_count     0
# char_count     0
# avg_word       0
# numerics       0
# dtype: int64

# %%
#sys.exit()
# describing dataset
kb_df.describe()
# Out:
#             Labels    stopwords        upper      hastags   word_count  \
# count  4900.000000  4900.000000  4900.000000  4900.000000  4900.000000
# mean      4.000000     1.782245     0.189184     0.000816     7.322245
# std       2.000204     3.014243     0.695776     0.045173     7.699502
# min       1.000000     0.000000     0.000000     0.000000     1.000000
# 25%       2.000000     0.000000     0.000000     0.000000     2.000000
# 50%       4.000000     1.000000     0.000000     0.000000     5.000000
# 75%       6.000000     2.000000     0.000000     0.000000    10.000000
# max       7.000000    42.000000    18.000000     3.000000   176.000000
#
#         char_count     avg_word  numerics
# count  4900.000000  4900.000000    4900.0
# mean     37.626122     4.578906       0.0
# std      40.381931     1.465191       0.0
# min       2.000000     2.000000       0.0
# 25%      12.000000     4.000000       0.0
# 50%      26.000000     4.375000       0.0
# 75%      49.000000     5.000000       0.0
# max     895.000000    49.000000       0.0

# %% [markdown]
# ### Data Visualization

# %%
# univariate plot of labels
sns.countplot(x = 'Labels', data=kb_df)
plt.show()

# %%
# univariate plot of stopwords
sns.countplot(x = 'stopwords', data=kb_df)
plt.show()

# %%
# univariate plot of upper words
sns.countplot(x = 'upper', data=kb_df)
plt.show()

# %%
# univariate plot of hashtags
sns.countplot(x = 'hastags', data=kb_df)
plt.show()

# %%
# univariate plot of word
sns.boxplot(x = 'word_count', data=kb_df)
plt.show()

# %%
# univariate plot of characters
sns.boxplot(x = 'char_count', data=kb_df)
plt.show()

# %%
# univariate plot of avg words
sns.boxplot(x = 'avg_word', data=kb_df)
plt.show()

# %%
#relation between Labels and stopwords.
sns.boxplot(x = 'Labels', y = 'stopwords', data = kb_df)
plt.xlabel("Labels")
plt.ylabel("Stopwords")
plt.show()

# %%
#relation between Labels and upperwords.
sns.boxplot(x = 'Labels', y = 'upper', data = kb_df)
plt.xlabel("Labels")
plt.ylabel("Upper Words")
plt.show()

# %%
#relation between Labels and word count.
sns.boxplot(x = 'Labels', y = 'word_count', data = kb_df)
plt.xlabel("Labels")
plt.ylabel("Word Count")
plt.show()

# %%
#relation between Labels and Char count.
sns.boxplot(x = 'Labels', y = 'char_count', data = kb_df)
plt.xlabel("Labels")
plt.ylabel("Character Count")
plt.show()

# %%
#relation between Labels and Average words.
sns.boxplot(x = 'Labels', y = 'avg_word', data = kb_df)
plt.xlabel("Labels")
plt.ylabel("Average Word")
plt.show()

# %%
# lm plot - Multivariate plot of word count, char count, labels
sns.lmplot(x='word_count',y = 'char_count',hue='Labels',data=kb_df,fit_reg=False)
plt.show()

# %%
# lm plot - Multivariate plot of word count, Average word, labels
sns.lmplot(x='word_count',y = 'avg_word',hue='Labels',data=kb_df,fit_reg=False)
plt.show()

# %%
# lm plot - Multivariate plot of char count, Average word, labels
sns.lmplot(x='char_count',y = 'avg_word',hue='Labels',data=kb_df,fit_reg=False)
plt.show()

# %%
# lm plot - Multivariate plot of word count, stopwords, labels
sns.lmplot(x='word_count',y = 'stopwords',hue='Labels',data=kb_df,fit_reg=False)
plt.show()
